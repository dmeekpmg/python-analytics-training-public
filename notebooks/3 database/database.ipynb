# %% [markdown]
# # SQLAlchemy
#
# - Set up the model in data.model
# - Create the database and migrate to newer versions using alembic
# - Connect using SQLAlchemy

# %%
import pandas as pd
from sqlalchemy import select
# We usually keep a single blank row between standard and 
# custom modules
from data.model import Shape, Trip, Stop, StopTime
from visualisations.maps import routemap, add_positions
from data.data import Session, path, engine

# %% [markdown]
# We can fetch trips using a simple select query

# %%
with Session() as session:
    stmt = select(Trip).limit(10)
    trips = session.execute(stmt).scalars().all()

trips
# Out:
# [Trip(route_id='2447_S886', service_id='294', id='1000095', trip_headsign='Mount View HS'),
#  Trip(route_id='2447_S871', service_id='294', id='1000097', trip_headsign='Mount View HS'),
#  Trip(route_id='2447_S879', service_id='294', id='1000103', trip_headsign='Cessnock PS'),
#  Trip(route_id='2454_8615', service_id='294', id='1000377', trip_headsign='Blaxland Station'),
#  Trip(route_id='2454_8311', service_id='294', id='1000381', trip_headsign='Warrimoo Primary'),
#  Trip(route_id='2454_8237', service_id='294', id='1000385', trip_headsign='Blaxland High School'),
#  Trip(route_id='2454_8530', service_id='248', id='1000387', trip_headsign='Mt Riverview'),
#  Trip(route_id='2454_8716', service_id='294', id='1000403', trip_headsign='Blue Mtns Hospital'),
#  Trip(route_id='2454_8728', service_id='294', id='1001298', trip_headsign='Wentworth Falls Stn'),
#  Trip(route_id='2446_880', service_id='56', id='1004848', trip_headsign='Campbelltown')]

# %% [markdown]
# And we can inspect individual values

# %%
trips[0].route_id
# Out:
# '2447_S886'

# %% [markdown]
# If we need all records in a dataframe, just use pd.read_sql

# %%
trips_dataframe = pd.read_sql(select(Trip), engine)

# %% [markdown]
# Sqlalchemy allows us to write succinct queries in a pythonic way. Notice
# that in the query below, we didn't have to specific how the join is
# defined. This is because it's set up once in the model, and can then be
# easily reused in future queries.

# %%
with Session() as session:
    stmt = select(Shape).join(Trip).where(Trip.id == 1948209)
    shape = session.execute(stmt).scalars().all()

shape
# Out:
# [Shape(id='151217', lat=-33.874502, lon=150.9289512, sequence=1, dist_traveled=0.0),
#  Shape(id='151217', lat=-33.8745039, lon=150.9289457, sequence=2, dist_traveled=6.0),
#  Shape(id='151217', lat=-33.8742754, lon=150.9279578, sequence=3, dist_traveled=101.0),
#  Shape(id='151217', lat=-33.874062, lon=150.9270657, sequence=4, dist_traveled=187.0),
#  Shape(id='151217', lat=-33.8739998, lon=150.9267969, sequence=5, dist_traveled=212.0),
#  Shape(id='151217', lat=-33.8739998, lon=150.9267969, sequence=6, dist_traveled=227.0),
#  Shape(id='151217', lat=-33.8737898, lon=150.925894, sequence=7, dist_traveled=314.0),
#  Shape(id='151217', lat=-33.873751, lon=150.9257328, sequence=8, dist_traveled=329.0),
#  Shape(id='151217', lat=-33.8732564, lon=150.9258096, sequence=9, dist_traveled=384.0),
#  Shape(id='151217', lat=-33.872959, lon=150.9258168, sequence=10, dist_traveled=417.0),
#  Shape(id='151217', lat=-33.8726064, lon=150.9257605, sequence=11, dist_traveled=457.0),
#  Shape(id='151217', lat=-33.8719352, lon=150.9255281, sequence=12, dist_traveled=534.0),
#  Shape(id='151217', lat=-33.8711633, lon=150.9252009, sequence=13, dist_traveled=625.0),
#  Shape(id='151217', lat=-33.8706563, lon=150.9250834, sequence=14, dist_traveled=682.0),
#  Shape(id='151217', lat=-33.870223, lon=150.9250507, sequence=15, dist_traveled=731.0),
#  Shape(id='151217', lat=-33.869656, lon=150.9251184, sequence=16, dist_traveled=794.0),
#  Shape(id='151217', lat=-33.8695487, lon=150.9246346, sequence=17, dist_traveled=840.0),
#  Shape(id='151217', lat=-33.8695341, lon=150.9245701, sequence=18, dist_traveled=846.0),
#  Shape(id='151217', lat=-33.8695341, lon=150.9245701, sequence=19, dist_traveled=862.0),
#  Shape(id='151217', lat=-33.8689655, lon=150.9221302, sequence=20, dist_traveled=1096.0),
#  Shape(id='151217', lat=-33.8689554, lon=150.9220656, sequence=21, dist_traveled=1102.0),
#  Shape(id='151217', lat=-33.8688105, lon=150.9214432, sequence=22, dist_traveled=1162.0),
#  Shape(id='151217', lat=-33.8688105, lon=150.9214432, sequence=23, dist_traveled=1176.0),
#  Shape(id='151217', lat=-33.8685859, lon=150.9204747, sequence=24, dist_traveled=1269.0),
#  Shape(id='151217', lat=-33.8684405, lon=150.9198729, sequence=25, dist_traveled=1327.0),
#  Shape(id='151217', lat=-33.8684142, lon=150.9197579, sequence=26, dist_traveled=1338.0),
#  Shape(id='151217', lat=-33.8684142, lon=150.9197579, sequence=27, dist_traveled=1354.0),
#  Shape(id='151217', lat=-33.8683723, lon=150.9195719, sequence=28, dist_traveled=1372.0),
#  Shape(id='151217', lat=-33.8682485, lon=150.9197155, sequence=29, dist_traveled=1391.0),
#  Shape(id='151217', lat=-33.868336, lon=150.920256, sequence=30, dist_traveled=1442.0),
#  Shape(id='151217', lat=-33.868336, lon=150.920256, sequence=31, dist_traveled=1455.0),
#  Shape(id='151217', lat=-33.8683391, lon=150.9202753, sequence=32, dist_traveled=1457.0),
#  Shape(id='151217', lat=-33.8683672, lon=150.9203395, sequence=33, dist_traveled=1463.0),
#  Shape(id='151217', lat=-33.8685859, lon=150.9204747, sequence=34, dist_traveled=1491.0),
#  Shape(id='151217', lat=-33.8684405, lon=150.9198729, sequence=35, dist_traveled=1549.0),
#  Shape(id='151217', lat=-33.8684142, lon=150.9197579, sequence=36, dist_traveled=1560.0),
#  Shape(id='151217', lat=-33.8684142, lon=150.9197579, sequence=37, dist_traveled=1576.0),
#  Shape(id='151217', lat=-33.8683723, lon=150.9195719, sequence=38, dist_traveled=1594.0),
#  Shape(id='151217', lat=-33.8683429, lon=150.9194321, sequence=39, dist_traveled=1607.0),
#  Shape(id='151217', lat=-33.8681872, lon=150.9187549, sequence=40, dist_traveled=1672.0),
#  Shape(id='151217', lat=-33.868125, lon=150.9184916, sequence=41, dist_traveled=1697.0),
#  Shape(id='151217', lat=-33.868125, lon=150.9184916, sequence=42, dist_traveled=1713.0),
#  Shape(id='151217', lat=-33.8680123, lon=150.9180133, sequence=43, dist_traveled=1759.0),
#  Shape(id='151217', lat=-33.8679815, lon=150.9177871, sequence=44, dist_traveled=1780.0),
#  Shape(id='151217', lat=-33.8678552, lon=150.9167201, sequence=45, dist_traveled=1879.0),
#  Shape(id='151217', lat=-33.8677565, lon=150.9159474, sequence=46, dist_traveled=1952.0),
#  Shape(id='151217', lat=-33.8677565, lon=150.9159474, sequence=47, dist_traveled=1971.0),
#  Shape(id='151217', lat=-33.8677409, lon=150.9158257, sequence=48, dist_traveled=1982.0),
#  Shape(id='151217', lat=-33.8676062, lon=150.9147913, sequence=49, dist_traveled=2079.0),
#  Shape(id='151217', lat=-33.8675743, lon=150.9145575, sequence=50, dist_traveled=2101.0),
#  Shape(id='151217', lat=-33.8675743, lon=150.9145575, sequence=51, dist_traveled=2116.0),
#  Shape(id='151217', lat=-33.8675444, lon=150.9143388, sequence=52, dist_traveled=2137.0),
#  Shape(id='151217', lat=-33.8674613, lon=150.9136923, sequence=53, dist_traveled=2197.0),
#  Shape(id='151217', lat=-33.8674395, lon=150.9134658, sequence=54, dist_traveled=2218.0),
#  Shape(id='151217', lat=-33.8674273, lon=150.9132823, sequence=55, dist_traveled=2235.0),
#  Shape(id='151217', lat=-33.8674342, lon=150.9131525, sequence=56, dist_traveled=2247.0),
#  Shape(id='151217', lat=-33.867441, lon=150.9130226, sequence=57, dist_traveled=2259.0),
#  Shape(id='151217', lat=-33.8674651, lon=150.9128491, sequence=58, dist_traveled=2276.0),
#  Shape(id='151217', lat=-33.8674899, lon=150.9127187, sequence=59, dist_traveled=2288.0),
#  Shape(id='151217', lat=-33.8675153, lon=150.9126208, sequence=60, dist_traveled=2298.0),
#  Shape(id='151217', lat=-33.8675333, lon=150.9126204, sequence=61, dist_traveled=2300.0),
#  Shape(id='151217', lat=-33.867551, lon=150.9125984, sequence=62, dist_traveled=2302.0),
#  Shape(id='151217', lat=-33.8675506, lon=150.9125767, sequence=63, dist_traveled=2304.0),
#  Shape(id='151217', lat=-33.8675322, lon=150.9125556, sequence=64, dist_traveled=2307.0),
#  Shape(id='151217', lat=-33.8675751, lon=150.9124248, sequence=65, dist_traveled=2320.0),
#  Shape(id='151217', lat=-33.8676182, lon=150.9123049, sequence=66, dist_traveled=2332.0),
#  Shape(id='151217', lat=-33.8676704, lon=150.9121955, sequence=67, dist_traveled=2344.0),
#  Shape(id='151217', lat=-33.8677227, lon=150.9120861, sequence=68, dist_traveled=2356.0),
#  Shape(id='151217', lat=-33.8677839, lon=150.9119766, sequence=69, dist_traveled=2368.0),
#  Shape(id='151217', lat=-33.8678544, lon=150.9118776, sequence=70, dist_traveled=2380.0),
#  Shape(id='151217', lat=-33.8680045, lon=150.9116902, sequence=71, dist_traveled=2404.0),
#  Shape(id='151217', lat=-33.8680841, lon=150.9116017, sequence=72, dist_traveled=2416.0),
#  Shape(id='151217', lat=-33.8681995, lon=150.9114908, sequence=73, dist_traveled=2432.0),
#  Shape(id='151217', lat=-33.8682885, lon=150.9114238, sequence=74, dist_traveled=2444.0),
#  Shape(id='151217', lat=-33.8683866, lon=150.9113566, sequence=75, dist_traveled=2456.0),
#  Shape(id='151217', lat=-33.8684491, lon=150.9113226, sequence=76, dist_traveled=2464.0),
#  Shape(id='151217', lat=-33.8685473, lon=150.9112662, sequence=77, dist_traveled=2476.0),
#  Shape(id='151217', lat=-33.868718, lon=150.9112296, sequence=78, dist_traveled=2495.0),
#  Shape(id='151217', lat=-33.8690074, lon=150.9111717, sequence=79, dist_traveled=2528.0),
#  Shape(id='151217', lat=-33.8690074, lon=150.9111717, sequence=80, dist_traveled=2542.0),
#  Shape(id='151217', lat=-33.8696436, lon=150.9110449, sequence=81, dist_traveled=2613.0),
#  Shape(id='151217', lat=-33.8700391, lon=150.9109715, sequence=82, dist_traveled=2658.0),
#  Shape(id='151217', lat=-33.8700391, lon=150.9109715, sequence=83, dist_traveled=2673.0),
#  Shape(id='151217', lat=-33.8706413, lon=150.9108584, sequence=84, dist_traveled=2740.0),
#  Shape(id='151217', lat=-33.8705165, lon=150.9098778, sequence=85, dist_traveled=2832.0),
#  Shape(id='151217', lat=-33.8704334, lon=150.9092313, sequence=86, dist_traveled=2893.0),
#  Shape(id='151217', lat=-33.8703185, lon=150.9083045, sequence=87, dist_traveled=2979.0),
#  Shape(id='151217', lat=-33.8701933, lon=150.9073022, sequence=88, dist_traveled=3073.0),
#  Shape(id='151217', lat=-33.8700581, lon=150.9062462, sequence=89, dist_traveled=3172.0),
#  Shape(id='151217', lat=-33.8707225, lon=150.905549, sequence=90, dist_traveled=3270.0),
#  Shape(id='151217', lat=-33.8712364, lon=150.9050176, sequence=91, dist_traveled=3345.0),
#  Shape(id='151217', lat=-33.8715731, lon=150.9046634, sequence=92, dist_traveled=3395.0),
#  Shape(id='151217', lat=-33.8717322, lon=150.9044758, sequence=93, dist_traveled=3420.0),
#  Shape(id='151217', lat=-33.8717675, lon=150.9044317, sequence=94, dist_traveled=3425.0),
#  Shape(id='151217', lat=-33.8718563, lon=150.9043538, sequence=95, dist_traveled=3437.0),
#  Shape(id='151217', lat=-33.8719008, lon=150.9043203, sequence=96, dist_traveled=3443.0),
#  Shape(id='151217', lat=-33.8719454, lon=150.9042868, sequence=97, dist_traveled=3449.0),
#  Shape(id='151217', lat=-33.8719991, lon=150.9042639, sequence=98, dist_traveled=3455.0),
#  Shape(id='151217', lat=-33.8721155, lon=150.9042178, sequence=99, dist_traveled=3469.0),
#  Shape(id='151217', lat=-33.8722321, lon=150.9041825, sequence=100, dist_traveled=3482.0),
#  Shape(id='151217', lat=-33.8723758, lon=150.9041466, sequence=101, dist_traveled=3499.0),
#  Shape(id='151217', lat=-33.8725198, lon=150.9041322, sequence=102, dist_traveled=3515.0),
#  Shape(id='151217', lat=-33.8726548, lon=150.9041181, sequence=103, dist_traveled=3530.0),
#  Shape(id='151217', lat=-33.872889, lon=150.9041016, sequence=104, dist_traveled=3556.0),
#  Shape(id='151217', lat=-33.873024, lon=150.9040875, sequence=105, dist_traveled=3571.0),
#  Shape(id='151217', lat=-33.8734279, lon=150.9039803, sequence=106, dist_traveled=3617.0),
#  Shape(id='151217', lat=-33.8734728, lon=150.9039684, sequence=107, dist_traveled=3622.0),
#  Shape(id='151217', lat=-33.8735532, lon=150.9039232, sequence=108, dist_traveled=3632.0),
#  Shape(id='151217', lat=-33.8737049, lon=150.903833, sequence=109, dist_traveled=3650.0),
#  Shape(id='151217', lat=-33.8739266, lon=150.9036114, sequence=110, dist_traveled=3682.0),
#  Shape(id='151217', lat=-33.8739795, lon=150.9035452, sequence=111, dist_traveled=3691.0),
#  Shape(id='151217', lat=-33.8742888, lon=150.9031701, sequence=112, dist_traveled=3740.0),
#  Shape(id='151217', lat=-33.874593, lon=150.903033, sequence=113, dist_traveled=3776.0),
#  Shape(id='151217', lat=-33.874772, lon=150.9029529, sequence=114, dist_traveled=3797.0),
#  Shape(id='151217', lat=-33.8750854, lon=150.9028263, sequence=115, dist_traveled=3834.0),
#  Shape(id='151217', lat=-33.875166, lon=150.9027919, sequence=116, dist_traveled=3843.0),
#  Shape(id='151217', lat=-33.8752105, lon=150.9027584, sequence=117, dist_traveled=3849.0),
#  Shape(id='151217', lat=-33.8752818, lon=150.9027134, sequence=118, dist_traveled=3858.0),
#  Shape(id='151217', lat=-33.875344, lon=150.9026579, sequence=119, dist_traveled=3867.0),
#  Shape(id='151217', lat=-33.8754062, lon=150.9026023, sequence=120, dist_traveled=3875.0),
#  Shape(id='151217', lat=-33.8755298, lon=150.9024479, sequence=121, dist_traveled=3895.0),
#  Shape(id='151217', lat=-33.8751895, lon=150.9020563, sequence=122, dist_traveled=3947.0),
#  Shape(id='151217', lat=-33.8748843, lon=150.9016097, sequence=123, dist_traveled=4001.0),
#  Shape(id='151217', lat=-33.8747458, lon=150.9014185, sequence=124, dist_traveled=4024.0),
#  Shape(id='151217', lat=-33.8746632, lon=150.9013341, sequence=125, dist_traveled=4036.0),
#  Shape(id='151217', lat=-33.8744523, lon=150.901123, sequence=126, dist_traveled=4067.0),
#  Shape(id='151217', lat=-33.8742234, lon=150.9009233, sequence=127, dist_traveled=4098.0),
#  Shape(id='151217', lat=-33.8739039, lon=150.9006933, sequence=128, dist_traveled=4139.0),
#  Shape(id='151217', lat=-33.8732666, lon=150.9003305, sequence=129, dist_traveled=4218.0),
#  Shape(id='151217', lat=-33.8732293, lon=150.900312, sequence=130, dist_traveled=4222.0),
#  Shape(id='151217', lat=-33.8732293, lon=150.900312, sequence=131, dist_traveled=4240.0),
#  Shape(id='151217', lat=-33.8726846, lon=150.9000421, sequence=132, dist_traveled=4305.0),
#  Shape(id='151217', lat=-33.8727815, lon=150.89991, sequence=133, dist_traveled=4321.0),
#  Shape(id='151217', lat=-33.8734692, lon=150.898996, sequence=134, dist_traveled=4435.0),
#  Shape(id='151217', lat=-33.8738571, lon=150.8984784, sequence=135, dist_traveled=4500.0),
#  Shape(id='151217', lat=-33.875667, lon=150.8962179, sequence=136, dist_traveled=4790.0),
#  Shape(id='151217', lat=-33.8758699, lon=150.8959535, sequence=137, dist_traveled=4823.0),
#  Shape(id='151217', lat=-33.876223, lon=150.8955124, sequence=138, dist_traveled=4879.0),
#  Shape(id='151217', lat=-33.8770884, lon=150.8944426, sequence=139, dist_traveled=5017.0),
#  Shape(id='151217', lat=-33.8772826, lon=150.8942, sequence=140, dist_traveled=5048.0),
#  Shape(id='151217', lat=-33.8778653, lon=150.8934722, sequence=141, dist_traveled=5142.0),
#  Shape(id='151217', lat=-33.8781303, lon=150.8931522, sequence=142, dist_traveled=5184.0),
#  Shape(id='151217', lat=-33.8792263, lon=150.8918604, sequence=143, dist_traveled=5354.0),
#  Shape(id='151217', lat=-33.8798185, lon=150.8911647, sequence=144, dist_traveled=5446.0),
#  Shape(id='151217', lat=-33.8802867, lon=150.8906019, sequence=145, dist_traveled=5520.0),
#  Shape(id='151217', lat=-33.8804022, lon=150.8905017, sequence=146, dist_traveled=5535.0),
#  Shape(id='151217', lat=-33.8805039, lon=150.8903857, sequence=147, dist_traveled=5551.0),
#  Shape(id='151217', lat=-33.8805039, lon=150.8903857, sequence=148, dist_traveled=5561.0),
#  Shape(id='151217', lat=-33.8813396, lon=150.88943, sequence=149, dist_traveled=5689.0),
#  Shape(id='151217', lat=-33.8815541, lon=150.8893166, sequence=150, dist_traveled=5715.0),
#  Shape(id='151217', lat=-33.8816168, lon=150.8892934, sequence=151, dist_traveled=5722.0),
#  Shape(id='151217', lat=-33.8816707, lon=150.8892813, sequence=152, dist_traveled=5728.0),
#  Shape(id='151217', lat=-33.8817248, lon=150.88928, sequence=153, dist_traveled=5734.0),
#  Shape(id='151217', lat=-33.8817971, lon=150.889289, sequence=154, dist_traveled=5742.0),
#  Shape(id='151217', lat=-33.8820376, lon=150.8896431, sequence=155, dist_traveled=5785.0),
#  Shape(id='151217', lat=-33.8820376, lon=150.8896431, sequence=156, dist_traveled=5795.0),
#  Shape(id='151217', lat=-33.8826203, lon=150.8905012, sequence=157, dist_traveled=5898.0),
#  Shape(id='151217', lat=-33.8832742, lon=150.8914581, sequence=158, dist_traveled=6012.0),
#  Shape(id='151217', lat=-33.8832742, lon=150.8914581, sequence=159, dist_traveled=6025.0),
#  Shape(id='151217', lat=-33.883499, lon=150.8917877, sequence=160, dist_traveled=6064.0),
#  Shape(id='151217', lat=-33.8844697, lon=150.8931909, sequence=161, dist_traveled=6233.0),
#  Shape(id='151217', lat=-33.8845992, lon=150.8933823, sequence=162, dist_traveled=6256.0),
#  Shape(id='151217', lat=-33.8854665, lon=150.894641, sequence=163, dist_traveled=6407.0),
#  Shape(id='151217', lat=-33.8854665, lon=150.894641, sequence=164, dist_traveled=6421.0),
#  Shape(id='151217', lat=-33.8855146, lon=150.8947112, sequence=165, dist_traveled=6429.0),
#  Shape(id='151217', lat=-33.8862083, lon=150.895732, sequence=166, dist_traveled=6551.0),
#  Shape(id='151217', lat=-33.8862926, lon=150.8959138, sequence=167, dist_traveled=6571.0),
#  Shape(id='151217', lat=-33.8862747, lon=150.895925, sequence=168, dist_traveled=6573.0),
#  Shape(id='151217', lat=-33.8862479, lon=150.8959365, sequence=169, dist_traveled=6576.0),
#  Shape(id='151217', lat=-33.8862212, lon=150.8959588, sequence=170, dist_traveled=6580.0),
#  Shape(id='151217', lat=-33.8862037, lon=150.8959916, sequence=171, dist_traveled=6583.0),
#  Shape(id='151217', lat=-33.8861953, lon=150.8960243, sequence=172, dist_traveled=6586.0),
#  Shape(id='151217', lat=-33.886187, lon=150.8960677, sequence=173, dist_traveled=6590.0),
#  Shape(id='151217', lat=-33.8861883, lon=150.8961434, sequence=174, dist_traveled=6597.0),
#  Shape(id='151217', lat=-33.8862069, lon=150.8961754, sequence=175, dist_traveled=6601.0),
#  Shape(id='151217', lat=-33.8862255, lon=150.8962073, sequence=176, dist_traveled=6605.0),
#  Shape(id='151217', lat=-33.8862439, lon=150.8962285, sequence=177, dist_traveled=6607.0),
#  Shape(id='151217', lat=-33.8862713, lon=150.8962495, sequence=178, dist_traveled=6611.0),
#  Shape(id='151217', lat=-33.8862985, lon=150.8962596, sequence=179, dist_traveled=6614.0),
#  Shape(id='151217', lat=-33.8863616, lon=150.896258, sequence=180, dist_traveled=6621.0),
#  Shape(id='151217', lat=-33.8863884, lon=150.8962466, sequence=181, dist_traveled=6624.0),
#  Shape(id='151217', lat=-33.8864151, lon=150.8962243, sequence=182, dist_traveled=6628.0),
#  Shape(id='151217', lat=-33.8864418, lon=150.896202, sequence=183, dist_traveled=6632.0),
#  Shape(id='151217', lat=-33.8864593, lon=150.8961692, sequence=184, dist_traveled=6635.0),
#  Shape(id='151217', lat=-33.8866702, lon=150.8963802, sequence=185, dist_traveled=6666.0),
#  Shape(id='151217', lat=-33.8870492, lon=150.8969223, sequence=186, dist_traveled=6731.0),
#  Shape(id='151217', lat=-33.8874931, lon=150.8975709, sequence=187, dist_traveled=6809.0),
#  Shape(id='151217', lat=-33.8880451, lon=150.8983769, sequence=188, dist_traveled=6905.0),
#  Shape(id='151217', lat=-33.8880451, lon=150.8983769, sequence=189, dist_traveled=6927.0),
#  Shape(id='151217', lat=-33.8888247, lon=150.8995168, sequence=190, dist_traveled=7063.0),
#  Shape(id='151217', lat=-33.8899714, lon=150.9011969, sequence=191, dist_traveled=7264.0),
#  Shape(id='151217', lat=-33.8899537, lon=150.901219, sequence=192, dist_traveled=7267.0),
#  Shape(id='151217', lat=-33.8899451, lon=150.9012408, sequence=193, dist_traveled=7269.0),
#  Shape(id='151217', lat=-33.8899366, lon=150.9012735, sequence=194, dist_traveled=7272.0),
#  Shape(id='151217', lat=-33.8899372, lon=150.9013059, sequence=195, dist_traveled=7275.0),
#  Shape(id='151217', lat=-33.8899466, lon=150.9013273, sequence=196, dist_traveled=7277.0),
#  Shape(id='151217', lat=-33.8899468, lon=150.9013381, sequence=197, dist_traveled=7278.0),
#  Shape(id='151217', lat=-33.8899655, lon=150.9013809, sequence=198, dist_traveled=7283.0),
#  Shape(id='151217', lat=-33.8899839, lon=150.9014021, sequence=199, dist_traveled=7286.0),
#  Shape(id='151217', lat=-33.8900021, lon=150.9014124, sequence=200, dist_traveled=7288.0),
#  Shape(id='151217', lat=-33.8900294, lon=150.9014226, sequence=201, dist_traveled=7291.0),
#  Shape(id='151217', lat=-33.8900744, lon=150.9014215, sequence=202, dist_traveled=7296.0),
#  Shape(id='151217', lat=-33.8900923, lon=150.9014102, sequence=203, dist_traveled=7298.0),
#  Shape(id='151217', lat=-33.8901191, lon=150.9013987, sequence=204, dist_traveled=7301.0),
#  Shape(id='151217', lat=-33.8901368, lon=150.9013767, sequence=205, dist_traveled=7304.0),
#  Shape(id='151217', lat=-33.8901541, lon=150.901333, sequence=206, dist_traveled=7309.0),
#  Shape(id='151217', lat=-33.8901625, lon=150.9013004, sequence=207, dist_traveled=7312.0),
#  Shape(id='151217', lat=-33.8901616, lon=150.9012463, sequence=208, dist_traveled=7317.0),
#  Shape(id='151217', lat=-33.8901522, lon=150.9012249, sequence=209, dist_traveled=7319.0),
#  Shape(id='151217', lat=-33.8901336, lon=150.901193, sequence=210, dist_traveled=7323.0),
#  Shape(id='151217', lat=-33.8901154, lon=150.9011826, sequence=211, dist_traveled=7325.0),
#  Shape(id='151217', lat=-33.8906387, lon=150.9006724, sequence=212, dist_traveled=7400.0),
#  Shape(id='151217', lat=-33.8910217, lon=150.9002911, sequence=213, dist_traveled=7455.0),
#  Shape(id='151217', lat=-33.8910217, lon=150.9002911, sequence=214, dist_traveled=7468.0),
#  Shape(id='151217', lat=-33.8911618, lon=150.9001514, sequence=215, dist_traveled=7488.0),
#  Shape(id='151217', lat=-33.8911973, lon=150.9001181, sequence=216, dist_traveled=7493.0),
#  Shape(id='151217', lat=-33.8917383, lon=150.8995859, sequence=217, dist_traveled=7571.0),
#  Shape(id='151217', lat=-33.8925454, lon=150.8987984, sequence=218, dist_traveled=7686.0),
#  Shape(id='151217', lat=-33.8927272, lon=150.8986188, sequence=219, dist_traveled=7712.0),
#  Shape(id='151217', lat=-33.8927272, lon=150.8986188, sequence=220, dist_traveled=7726.0),
#  Shape(id='151217', lat=-33.8931395, lon=150.8982108, sequence=221, dist_traveled=7785.0),
#  Shape(id='151217', lat=-33.8936539, lon=150.8977116, sequence=222, dist_traveled=7858.0),
#  Shape(id='151217', lat=-33.8939201, lon=150.8974564, sequence=223, dist_traveled=7896.0),
#  Shape(id='151217', lat=-33.8940549, lon=150.8974315, sequence=224, dist_traveled=7911.0),
#  Shape(id='151217', lat=-33.8939925, lon=150.8969464, sequence=225, dist_traveled=7957.0),
#  Shape(id='151217', lat=-33.8940073, lon=150.896812, sequence=226, dist_traveled=7969.0),
#  Shape(id='151217', lat=-33.8940073, lon=150.896812, sequence=227, dist_traveled=7975.0),
#  Shape(id='151217', lat=-33.8940081, lon=150.8968055, sequence=228, dist_traveled=7975.0),
#  Shape(id='151217', lat=-33.8938955, lon=150.8960189, sequence=229, dist_traveled=8049.0),
#  Shape(id='151217', lat=-33.8938123, lon=150.8953722, sequence=230, dist_traveled=8110.0),
#  Shape(id='151217', lat=-33.893756, lon=150.8952439, sequence=231, dist_traveled=8123.0),
#  Shape(id='151217', lat=-33.8934781, lon=150.8932288, sequence=232, dist_traveled=8312.0),
#  Shape(id='151217', lat=-33.8936387, lon=150.8931275, sequence=233, dist_traveled=8332.0),
#  Shape(id='151217', lat=-33.8936646, lon=150.893062, sequence=234, dist_traveled=8339.0),
#  Shape(id='151217', lat=-33.8936213, lon=150.8927441, sequence=235, dist_traveled=8369.0),
#  Shape(id='151217', lat=-33.8936213, lon=150.8927441, sequence=236, dist_traveled=8374.0),
#  Shape(id='151217', lat=-33.8935925, lon=150.892534, sequence=237, dist_traveled=8393.0),
#  Shape(id='151217', lat=-33.8935649, lon=150.8925022, sequence=238, dist_traveled=8398.0),
#  Shape(id='151217', lat=-33.8934922, lon=150.8924716, sequence=239, dist_traveled=8406.0),
#  Shape(id='151217', lat=-33.8933659, lon=150.8924639, sequence=240, dist_traveled=8420.0),
#  Shape(id='151217', lat=-33.8934781, lon=150.8932288, sequence=241, dist_traveled=8492.0),
#  Shape(id='151217', lat=-33.893756, lon=150.8952439, sequence=242, dist_traveled=8681.0),
#  Shape(id='151217', lat=-33.8937406, lon=150.8953956, sequence=243, dist_traveled=8695.0),
#  Shape(id='151217', lat=-33.8938236, lon=150.8960315, sequence=244, dist_traveled=8755.0),
#  Shape(id='151217', lat=-33.8939364, lon=150.8968289, sequence=245, dist_traveled=8830.0),
#  Shape(id='151217', lat=-33.8939925, lon=150.8969464, sequence=246, dist_traveled=8842.0),
#  Shape(id='151217', lat=-33.8939977, lon=150.8969841, sequence=247, dist_traveled=8846.0),
#  Shape(id='151217', lat=-33.8939977, lon=150.8969841, sequence=248, dist_traveled=8860.0),
#  Shape(id='151217', lat=-33.8940549, lon=150.8974315, sequence=249, dist_traveled=8902.0),
#  Shape(id='151217', lat=-33.8939201, lon=150.8974564, sequence=250, dist_traveled=8917.0),
#  Shape(id='151217', lat=-33.8936539, lon=150.8977116, sequence=251, dist_traveled=8955.0),
#  Shape(id='151217', lat=-33.8931395, lon=150.8982108, sequence=252, dist_traveled=9029.0),
#  Shape(id='151217', lat=-33.8928717, lon=150.8984758, sequence=253, dist_traveled=9067.0),
#  Shape(id='151217', lat=-33.8928717, lon=150.8984758, sequence=254, dist_traveled=9083.0),
#  Shape(id='151217', lat=-33.8925454, lon=150.8987984, sequence=255, dist_traveled=9130.0),
#  Shape(id='151217', lat=-33.8917383, lon=150.8995859, sequence=256, dist_traveled=9245.0),
#  Shape(id='151217', lat=-33.8911973, lon=150.9001181, sequence=257, dist_traveled=9323.0),
#  Shape(id='151217', lat=-33.8911618, lon=150.9001514, sequence=258, dist_traveled=9328.0),
#  Shape(id='151217', lat=-33.8908923, lon=150.9004197, sequence=259, dist_traveled=9367.0),
#  Shape(id='151217', lat=-33.8908923, lon=150.9004197, sequence=260, dist_traveled=9381.0),
#  Shape(id='151217', lat=-33.8906387, lon=150.9006724, sequence=261, dist_traveled=9418.0),
#  Shape(id='151217', lat=-33.8901154, lon=150.9011826, sequence=262, dist_traveled=9493.0),
#  Shape(id='151217', lat=-33.890097, lon=150.9011614, sequence=263, dist_traveled=9496.0),
#  Shape(id='151217', lat=-33.8900698, lon=150.9011513, sequence=264, dist_traveled=9499.0),
#  Shape(id='151217', lat=-33.8900247, lon=150.9011524, sequence=265, dist_traveled=9504.0),
#  Shape(id='151217', lat=-33.8899891, lon=150.9011749, sequence=266, dist_traveled=9508.0),
#  Shape(id='151217', lat=-33.8899714, lon=150.9011969, sequence=267, dist_traveled=9511.0),
#  Shape(id='151217', lat=-33.8899537, lon=150.901219, sequence=268, dist_traveled=9514.0),
#  Shape(id='151217', lat=-33.8899451, lon=150.9012408, sequence=269, dist_traveled=9516.0),
#  Shape(id='151217', lat=-33.8899366, lon=150.9012735, sequence=270, dist_traveled=9519.0),
#  Shape(id='151217', lat=-33.8899372, lon=150.9013059, sequence=271, dist_traveled=9522.0),
#  Shape(id='151217', lat=-33.8899466, lon=150.9013273, sequence=272, dist_traveled=9525.0),
#  Shape(id='151217', lat=-33.8899468, lon=150.9013381, sequence=273, dist_traveled=9526.0),
#  Shape(id='151217', lat=-33.8899203, lon=150.9013712, sequence=274, dist_traveled=9530.0),
#  Shape(id='151217', lat=-33.8893599, lon=150.9019277, sequence=275, dist_traveled=9610.0),
#  Shape(id='151217', lat=-33.8893599, lon=150.9019277, sequence=276, dist_traveled=9625.0),
#  Shape(id='151217', lat=-33.889273, lon=150.9020141, sequence=277, dist_traveled=9638.0),
#  Shape(id='151217', lat=-33.8887674, lon=150.9025022, sequence=278, dist_traveled=9710.0),
#  Shape(id='151217', lat=-33.8882644, lon=150.9029913, sequence=279, dist_traveled=9781.0),
#  Shape(id='151217', lat=-33.8882644, lon=150.9029913, sequence=280, dist_traveled=9795.0),
#  Shape(id='151217', lat=-33.8879691, lon=150.9032786, sequence=281, dist_traveled=9838.0),
#  Shape(id='151217', lat=-33.8877119, lon=150.9035336, sequence=282, dist_traveled=9875.0),
#  Shape(id='151217', lat=-33.8873571, lon=150.9038774, sequence=283, dist_traveled=9925.0),
#  Shape(id='151217', lat=-33.8862683, lon=150.9049603, sequence=284, dist_traveled=10082.0),
#  Shape(id='151217', lat=-33.8862683, lon=150.9049603, sequence=285, dist_traveled=10097.0),
#  Shape(id='151217', lat=-33.8861424, lon=150.9050856, sequence=286, dist_traveled=10115.0),
#  Shape(id='151217', lat=-33.8860004, lon=150.9052188, sequence=287, dist_traveled=10135.0),
#  Shape(id='151217', lat=-33.8858964, lon=150.90547, sequence=288, dist_traveled=10161.0),
#  Shape(id='151217', lat=-33.8858799, lon=150.9055569, sequence=289, dist_traveled=10169.0),
#  Shape(id='151217', lat=-33.8858528, lon=150.9055575, sequence=290, dist_traveled=10172.0),
#  Shape(id='151217', lat=-33.885844, lon=150.9055686, sequence=291, dist_traveled=10173.0),
#  Shape(id='151217', lat=-33.8858262, lon=150.9055798, sequence=292, dist_traveled=10176.0),
#  Shape(id='151217', lat=-33.8858089, lon=150.9056235, sequence=293, dist_traveled=10180.0),
#  Shape(id='151217', lat=-33.8858098, lon=150.9056775, sequence=294, dist_traveled=10185.0),
#  Shape(id='151217', lat=-33.8858286, lon=150.9057203, sequence=295, dist_traveled=10190.0),
#  Shape(id='151217', lat=-33.8858376, lon=150.9057201, sequence=296, dist_traveled=10191.0),
#  Shape(id='151217', lat=-33.885856, lon=150.9057413, sequence=297, dist_traveled=10193.0),
#  Shape(id='151217', lat=-33.885874, lon=150.9057408, sequence=298, dist_traveled=10195.0),
#  Shape(id='151217', lat=-33.885876, lon=150.9058597, sequence=299, dist_traveled=10206.0),
#  Shape(id='151217', lat=-33.8859556, lon=150.906301, sequence=300, dist_traveled=10248.0),
#  Shape(id='151217', lat=-33.8859907, lon=150.9065077, sequence=301, dist_traveled=10268.0),
#  Shape(id='151217', lat=-33.8859907, lon=150.9065077, sequence=302, dist_traveled=10280.0),
#  Shape(id='151217', lat=-33.8860158, lon=150.9066563, sequence=303, dist_traveled=10294.0),
#  Shape(id='151217', lat=-33.8862311, lon=150.9081852, sequence=304, dist_traveled=10437.0),
#  Shape(id='151217', lat=-33.8862311, lon=150.9081852, sequence=305, dist_traveled=10452.0),
#  Shape(id='151217', lat=-33.8863028, lon=150.9086927, sequence=306, dist_traveled=10499.0),
#  Shape(id='151217', lat=-33.8863233, lon=150.9088327, sequence=307, dist_traveled=10513.0),
#  Shape(id='151217', lat=-33.8864064, lon=150.9094794, sequence=308, dist_traveled=10573.0),
#  Shape(id='151217', lat=-33.8865189, lon=150.9102659, sequence=309, dist_traveled=10647.0),
#  Shape(id='151217', lat=-33.8865099, lon=150.9102661, sequence=310, dist_traveled=10648.0),
#  Shape(id='151217', lat=-33.8864922, lon=150.9102882, sequence=311, dist_traveled=10651.0),
#  Shape(id='151217', lat=-33.8864928, lon=150.9103206, sequence=312, dist_traveled=10654.0),
#  Shape(id='151217', lat=-33.8865112, lon=150.9103418, sequence=313, dist_traveled=10657.0),
#  Shape(id='151217', lat=-33.8865292, lon=150.9103413, sequence=314, dist_traveled=10659.0),
#  Shape(id='151217', lat=-33.886554, lon=150.9105278, sequence=315, dist_traveled=10676.0),
#  Shape(id='151217', lat=-33.886554, lon=150.9105278, sequence=316, dist_traveled=10687.0),
#  Shape(id='151217', lat=-33.8866739, lon=150.9114298, sequence=317, dist_traveled=10772.0),
#  Shape(id='151217', lat=-33.8867658, lon=150.9120654, sequence=318, dist_traveled=10832.0),
#  Shape(id='151217', lat=-33.8868377, lon=150.9125826, sequence=319, dist_traveled=10880.0),
#  Shape(id='151217', lat=-33.8869293, lon=150.9131966, sequence=320, dist_traveled=10938.0),
#  Shape(id='151217', lat=-33.8870011, lon=150.9137138, sequence=321, dist_traveled=10986.0),
#  Shape(id='151217', lat=-33.8870629, lon=150.9141664, sequence=322, dist_traveled=11029.0),
#  Shape(id='151217', lat=-33.8866676, lon=150.9142517, sequence=323, dist_traveled=11073.0),
#  Shape(id='151217', lat=-33.8859666, lon=150.9143877, sequence=324, dist_traveled=11152.0),
#  Shape(id='151217', lat=-33.8852926, lon=150.9145231, sequence=325, dist_traveled=11228.0),
#  Shape(id='151217', lat=-33.8851219, lon=150.9145596, sequence=326, dist_traveled=11247.0),
#  Shape(id='151217', lat=-33.8844031, lon=150.9147069, sequence=327, dist_traveled=11328.0),
#  Shape(id='151217', lat=-33.8831988, lon=150.9149416, sequence=328, dist_traveled=11463.0),
#  Shape(id='151217', lat=-33.8824798, lon=150.915078, sequence=329, dist_traveled=11544.0),
#  Shape(id='151217', lat=-33.8824796, lon=150.9150672, sequence=330, dist_traveled=11545.0),
#  Shape(id='151217', lat=-33.8824336, lon=150.9150143, sequence=331, dist_traveled=11552.0),
#  Shape(id='151217', lat=-33.8824066, lon=150.9150149, sequence=332, dist_traveled=11555.0),
#  Shape(id='151217', lat=-33.8823887, lon=150.9150262, sequence=333, dist_traveled=11557.0),
#  Shape(id='151217', lat=-33.8823797, lon=150.9150264, sequence=334, dist_traveled=11558.0),
#  Shape(id='151217', lat=-33.8823709, lon=150.9150374, sequence=335, dist_traveled=11560.0),
#  Shape(id='151217', lat=-33.8823622, lon=150.9150593, sequence=336, dist_traveled=11562.0),
#  Shape(id='151217', lat=-33.8823534, lon=150.9150703, sequence=337, dist_traveled=11563.0),
#  Shape(id='151217', lat=-33.882354, lon=150.9151027, sequence=338, dist_traveled=11566.0),
#  Shape(id='151217', lat=-33.8815992, lon=150.9152616, sequence=339, dist_traveled=11651.0),
#  Shape(id='151217', lat=-33.8808984, lon=150.9154084, sequence=340, dist_traveled=11730.0),
#  Shape(id='151217', lat=-33.8796556, lon=150.915657, sequence=341, dist_traveled=11870.0),
#  Shape(id='151217', lat=-33.8796556, lon=150.915657, sequence=342, dist_traveled=11883.0),
#  Shape(id='151217', lat=-33.8792988, lon=150.9157284, sequence=343, dist_traveled=11923.0),
#  Shape(id='151217', lat=-33.8783464, lon=150.9159245, sequence=344, dist_traveled=12030.0),
#  Shape(id='151217', lat=-33.8778395, lon=150.9160222, sequence=345, dist_traveled=12087.0),
#  Shape(id='151217', lat=-33.8778395, lon=150.9160222, sequence=346, dist_traveled=12099.0),
#  Shape(id='151217', lat=-33.8775734, lon=150.916073, sequence=347, dist_traveled=12129.0),
#  Shape(id='151217', lat=-33.8768007, lon=150.9162324, sequence=348, dist_traveled=12216.0),
#  Shape(id='151217', lat=-33.875947, lon=150.9164045, sequence=349, dist_traveled=12312.0),
#  Shape(id='151217', lat=-33.8755072, lon=150.9164703, sequence=350, dist_traveled=12361.0),
#  Shape(id='151217', lat=-33.8755072, lon=150.9164703, sequence=351, dist_traveled=12372.0),
#  Shape(id='151217', lat=-33.8749127, lon=150.9165593, sequence=352, dist_traveled=12438.0),
#  Shape(id='151217', lat=-33.8749027, lon=150.9165055, sequence=353, dist_traveled=12443.0),
#  Shape(id='151217', lat=-33.874902, lon=150.9164623, sequence=354, dist_traveled=12447.0),
#  Shape(id='151217', lat=-33.8749099, lon=150.9163972, sequence=355, dist_traveled=12454.0),
#  Shape(id='151217', lat=-33.8749182, lon=150.9163538, sequence=356, dist_traveled=12458.0),
#  Shape(id='151217', lat=-33.874935, lon=150.9162777, sequence=357, dist_traveled=12465.0),
#  Shape(id='151217', lat=-33.8749434, lon=150.9162451, sequence=358, dist_traveled=12468.0),
#  Shape(id='151217', lat=-33.8749609, lon=150.9162122, sequence=359, dist_traveled=12472.0),
#  Shape(id='151217', lat=-33.874996, lon=150.9161573, sequence=360, dist_traveled=12478.0),
#  Shape(id='151217', lat=-33.8750402, lon=150.9161022, sequence=361, dist_traveled=12485.0),
#  Shape(id='151217', lat=-33.87512, lon=150.9160246, sequence=362, dist_traveled=12497.0),
#  Shape(id='151217', lat=-33.8770886, lon=150.9140633, sequence=363, dist_traveled=12780.0),
#  Shape(id='151217', lat=-33.8762056, lon=150.9130362, sequence=364, dist_traveled=12917.0),
#  Shape(id='151217', lat=-33.8757079, lon=150.9123997, sequence=365, dist_traveled=12998.0),
#  Shape(id='151217', lat=-33.8756144, lon=150.9122074, sequence=366, dist_traveled=13018.0),
#  Shape(id='151217', lat=-33.8755572, lon=150.912025, sequence=367, dist_traveled=13036.0),
#  Shape(id='151217', lat=-33.8755087, lon=150.9118208, sequence=368, dist_traveled=13056.0),
#  Shape(id='151217', lat=-33.8754782, lon=150.9116162, sequence=369, dist_traveled=13075.0),
#  Shape(id='151217', lat=-33.8754558, lon=150.9113573, sequence=370, dist_traveled=13099.0),
#  Shape(id='151217', lat=-33.8754422, lon=150.9110873, sequence=371, dist_traveled=13124.0),
#  Shape(id='151217', lat=-33.8754102, lon=150.9107962, sequence=372, dist_traveled=13151.0),
#  Shape(id='151217', lat=-33.8753523, lon=150.910041, sequence=373, dist_traveled=13222.0),
#  Shape(id='151217', lat=-33.8752852, lon=150.9092751, sequence=374, dist_traveled=13293.0),
#  Shape(id='151217', lat=-33.8752561, lon=150.9091569, sequence=375, dist_traveled=13304.0),
#  Shape(id='151217', lat=-33.8751724, lon=150.9090076, sequence=376, dist_traveled=13321.0),
#  Shape(id='151217', lat=-33.8750345, lon=150.9088488, sequence=377, dist_traveled=13342.0),
#  Shape(id='151217', lat=-33.8745009, lon=150.908224, sequence=378, dist_traveled=13425.0),
#  Shape(id='151217', lat=-33.8741423, lon=150.9086641, sequence=379, dist_traveled=13482.0),
#  Shape(id='151217', lat=-33.8741423, lon=150.9086641, sequence=380, dist_traveled=13498.0),
#  Shape(id='151217', lat=-33.8739621, lon=150.9088858, sequence=381, dist_traveled=13527.0),
#  Shape(id='151217', lat=-33.8738919, lon=150.9089956, sequence=382, dist_traveled=13540.0),
#  Shape(id='151217', lat=-33.8738827, lon=150.908985, sequence=383, dist_traveled=13541.0),
#  Shape(id='151217', lat=-33.8738462, lon=150.9089643, sequence=384, dist_traveled=13546.0),
#  Shape(id='151217', lat=-33.8738192, lon=150.9089649, sequence=385, dist_traveled=13549.0),
#  Shape(id='151217', lat=-33.8738014, lon=150.9089762, sequence=386, dist_traveled=13551.0),
#  Shape(id='151217', lat=-33.8737925, lon=150.9089872, sequence=387, dist_traveled=13552.0),
#  Shape(id='151217', lat=-33.8737747, lon=150.9089984, sequence=388, dist_traveled=13554.0),
#  Shape(id='151217', lat=-33.8737659, lon=150.9090095, sequence=389, dist_traveled=13556.0),
#  Shape(id='151217', lat=-33.8737572, lon=150.9090313, sequence=390, dist_traveled=13558.0),
#  Shape(id='151217', lat=-33.8737581, lon=150.9090853, sequence=391, dist_traveled=13563.0),
#  Shape(id='151217', lat=-33.8737769, lon=150.9091281, sequence=392, dist_traveled=13568.0),
#  Shape(id='151217', lat=-33.8737861, lon=150.9091387, sequence=393, dist_traveled=13569.0),
#  Shape(id='151217', lat=-33.8738043, lon=150.909149, sequence=394, dist_traveled=13571.0),
#  Shape(id='151217', lat=-33.8738133, lon=150.9091488, sequence=395, dist_traveled=13572.0),
#  Shape(id='151217', lat=-33.8737186, lon=150.9094106, sequence=396, dist_traveled=13599.0),
#  Shape(id='151217', lat=-33.873622, lon=150.9095643, sequence=397, dist_traveled=13616.0),
#  Shape(id='151217', lat=-33.8734809, lon=150.9097515, sequence=398, dist_traveled=13640.0),
#  Shape(id='151217', lat=-33.8734279, lon=150.9098176, sequence=399, dist_traveled=13648.0),
#  Shape(id='151217', lat=-33.8733039, lon=150.9099504, sequence=400, dist_traveled=13667.0),
#  Shape(id='151217', lat=-33.8731707, lon=150.9100725, sequence=401, dist_traveled=13685.0),
#  Shape(id='151217', lat=-33.8730284, lon=150.9101841, sequence=402, dist_traveled=13704.0),
#  Shape(id='151217', lat=-33.8728858, lon=150.9102849, sequence=403, dist_traveled=13723.0),
#  Shape(id='151217', lat=-33.8727429, lon=150.910364, sequence=404, dist_traveled=13740.0),
#  Shape(id='151217', lat=-33.8725819, lon=150.9104436, sequence=405, dist_traveled=13759.0),
#  Shape(id='151217', lat=-33.8724296, lon=150.9105014, sequence=406, dist_traveled=13777.0),
#  Shape(id='151217', lat=-33.872304, lon=150.9105369, sequence=407, dist_traveled=13791.0),
#  Shape(id='151217', lat=-33.8721962, lon=150.9105611, sequence=408, dist_traveled=13803.0),
#  Shape(id='151217', lat=-33.8719626, lon=150.91061, sequence=409, dist_traveled=13830.0),
#  Shape(id='151217', lat=-33.8716813, lon=150.9106623, sequence=410, dist_traveled=13861.0),
#  Shape(id='151217', lat=-33.8716813, lon=150.9106623, sequence=411, dist_traveled=13875.0),
#  Shape(id='151217', lat=-33.8714952, lon=150.9106971, sequence=412, dist_traveled=13896.0),
#  Shape(id='151217', lat=-33.8706413, lon=150.9108584, sequence=413, dist_traveled=13991.0),
#  Shape(id='151217', lat=-33.8696436, lon=150.9110449, sequence=414, dist_traveled=14103.0),
#  Shape(id='151217', lat=-33.868718, lon=150.9112296, sequence=415, dist_traveled=14208.0),
#  Shape(id='151217', lat=-33.8685473, lon=150.9112662, sequence=416, dist_traveled=14227.0),
#  Shape(id='151217', lat=-33.8684491, lon=150.9113226, sequence=417, dist_traveled=14239.0),
#  Shape(id='151217', lat=-33.8683866, lon=150.9113566, sequence=418, dist_traveled=14247.0),
#  Shape(id='151217', lat=-33.8682885, lon=150.9114238, sequence=419, dist_traveled=14259.0),
#  Shape(id='151217', lat=-33.8681995, lon=150.9114908, sequence=420, dist_traveled=14271.0),
#  Shape(id='151217', lat=-33.868156, lon=150.911533, sequence=421, dist_traveled=14277.0),
#  Shape(id='151217', lat=-33.868156, lon=150.911533, sequence=422, dist_traveled=14294.0),
#  Shape(id='151217', lat=-33.8680841, lon=150.9116017, sequence=423, dist_traveled=14304.0),
#  Shape(id='151217', lat=-33.8680045, lon=150.9116902, sequence=424, dist_traveled=14316.0),
#  Shape(id='151217', lat=-33.8678544, lon=150.9118776, sequence=425, dist_traveled=14340.0),
#  Shape(id='151217', lat=-33.8677839, lon=150.9119766, sequence=426, dist_traveled=14352.0),
#  Shape(id='151217', lat=-33.8677227, lon=150.9120861, sequence=427, dist_traveled=14364.0),
#  Shape(id='151217', lat=-33.8676704, lon=150.9121955, sequence=428, dist_traveled=14376.0),
#  Shape(id='151217', lat=-33.8676182, lon=150.9123049, sequence=429, dist_traveled=14388.0),
#  Shape(id='151217', lat=-33.8675751, lon=150.9124248, sequence=430, dist_traveled=14400.0),
#  Shape(id='151217', lat=-33.8675322, lon=150.9125556, sequence=431, dist_traveled=14413.0),
#  Shape(id='151217', lat=-33.8675232, lon=150.9125558, sequence=432, dist_traveled=14414.0),
#  Shape(id='151217', lat=-33.8675054, lon=150.912567, sequence=433, dist_traveled=14416.0),
#  Shape(id='151217', lat=-33.8674964, lon=150.9125673, sequence=434, dist_traveled=14417.0),
#  Shape(id='151217', lat=-33.8671313, lon=150.9123059, sequence=435, dist_traveled=14464.0),
#  Shape(id='151217', lat=-33.867084, lon=150.9121774, sequence=436, dist_traveled=14477.0),
#  Shape(id='151217', lat=-33.8670454, lon=150.912027, sequence=437, dist_traveled=14492.0),
#  Shape(id='151217', lat=-33.8670147, lon=150.9118115, sequence=438, dist_traveled=14512.0),
#  Shape(id='151217', lat=-33.8669588, lon=150.9117048, sequence=439, dist_traveled=14524.0),
#  Shape(id='151217', lat=-33.8668418, lon=150.9117185, sequence=440, dist_traveled=14537.0),
#  Shape(id='151217', lat=-33.866771, lon=150.9117959, sequence=441, dist_traveled=14547.0),
#  Shape(id='151217', lat=-33.866773, lon=150.9119147, sequence=442, dist_traveled=14558.0),
#  Shape(id='151217', lat=-33.8668296, lon=150.9120647, sequence=443, dist_traveled=14574.0),
#  Shape(id='151217', lat=-33.8668709, lon=150.9121047, sequence=444, dist_traveled=14579.0),
#  Shape(id='151217', lat=-33.8668709, lon=150.9121047, sequence=445, dist_traveled=14590.0),
#  Shape(id='151217', lat=-33.866958, lon=150.9121912, sequence=446, dist_traveled=14602.0),
#  Shape(id='151217', lat=-33.8671313, lon=150.9123059, sequence=447, dist_traveled=14624.0),
#  Shape(id='151217', lat=-33.8674964, lon=150.9125673, sequence=448, dist_traveled=14672.0),
#  Shape(id='151217', lat=-33.8674971, lon=150.9126105, sequence=449, dist_traveled=14676.0),
#  Shape(id='151217', lat=-33.8675063, lon=150.9126211, sequence=450, dist_traveled=14677.0),
#  Shape(id='151217', lat=-33.8675153, lon=150.9126208, sequence=451, dist_traveled=14678.0),
#  Shape(id='151217', lat=-33.8674899, lon=150.9127187, sequence=452, dist_traveled=14687.0),
#  Shape(id='151217', lat=-33.8674651, lon=150.9128491, sequence=453, dist_traveled=14700.0),
#  Shape(id='151217', lat=-33.867441, lon=150.9130226, sequence=454, dist_traveled=14716.0),
#  Shape(id='151217', lat=-33.8674342, lon=150.9131525, sequence=455, dist_traveled=14728.0),
#  Shape(id='151217', lat=-33.8674273, lon=150.9132823, sequence=456, dist_traveled=14740.0),
#  Shape(id='151217', lat=-33.8674395, lon=150.9134658, sequence=457, dist_traveled=14757.0),
#  Shape(id='151217', lat=-33.8674613, lon=150.9136923, sequence=458, dist_traveled=14778.0),
#  Shape(id='151217', lat=-33.8672636, lon=150.9137295, sequence=459, dist_traveled=14801.0),
#  Shape(id='151217', lat=-33.8671462, lon=150.9137215, sequence=460, dist_traveled=14814.0),
#  Shape(id='151217', lat=-33.8670556, lon=150.9136913, sequence=461, dist_traveled=14824.0),
#  Shape(id='151217', lat=-33.8670099, lon=150.91366, sequence=462, dist_traveled=14830.0),
#  Shape(id='151217', lat=-33.8669642, lon=150.9136179, sequence=463, dist_traveled=14836.0),
#  Shape(id='151217', lat=-33.8665262, lon=150.9133151, sequence=464, dist_traveled=14892.0),
#  Shape(id='151217', lat=-33.8664444, lon=150.9132738, sequence=465, dist_traveled=14902.0),
#  Shape(id='151217', lat=-33.8664079, lon=150.9132531, sequence=466, dist_traveled=14907.0),
#  Shape(id='151217', lat=-33.8663447, lon=150.9132438, sequence=467, dist_traveled=14914.0),
#  Shape(id='151217', lat=-33.8663596, lon=150.9130597, sequence=468, dist_traveled=14931.0),
#  Shape(id='151217', lat=-33.8663581, lon=150.9129733, sequence=469, dist_traveled=14939.0),
#  Shape(id='151217', lat=-33.8663372, lon=150.9128009, sequence=470, dist_traveled=14955.0),
#  Shape(id='151217', lat=-33.8663177, lon=150.9127149, sequence=471, dist_traveled=14963.0),
#  Shape(id='151217', lat=-33.8662892, lon=150.9126291, sequence=472, dist_traveled=14972.0),
#  Shape(id='151217', lat=-33.8662702, lon=150.9125755, sequence=473, dist_traveled=14977.0),
#  Shape(id='151217', lat=-33.8661408, lon=150.9123841, sequence=474, dist_traveled=15000.0),
#  Shape(id='151217', lat=-33.8658726, lon=150.9119907, sequence=475, dist_traveled=15047.0),
#  Shape(id='151217', lat=-33.8651803, lon=150.9110456, sequence=476, dist_traveled=15163.0),
#  Shape(id='151217', lat=-33.8654879, lon=150.9105733, sequence=477, dist_traveled=15219.0),
#  Shape(id='151217', lat=-33.8661943, lon=150.9096914, sequence=478, dist_traveled=15332.0),
#  Shape(id='151217', lat=-33.8674709, lon=150.9078767, sequence=479, dist_traveled=15552.0),
#  Shape(id='151217', lat=-33.8698185, lon=150.9043496, sequence=480, dist_traveled=15969.0),
#  Shape(id='151217', lat=-33.8701348, lon=150.9038663, sequence=481, dist_traveled=16026.0),
#  Shape(id='151217', lat=-33.8706182, lon=150.9031302, sequence=482, dist_traveled=16113.0),
#  Shape(id='151217', lat=-33.8706898, lon=150.903096, sequence=483, dist_traveled=16121.0),
#  Shape(id='151217', lat=-33.8712256, lon=150.9022614, sequence=484, dist_traveled=16219.0),
#  Shape(id='151217', lat=-33.8713744, lon=150.9019983, sequence=485, dist_traveled=16248.0),
#  Shape(id='151217', lat=-33.8720421, lon=150.9009659, sequence=486, dist_traveled=16369.0),
#  Shape(id='151217', lat=-33.8726846, lon=150.9000421, sequence=487, dist_traveled=16480.0),
#  Shape(id='151217', lat=-33.8720921, lon=150.8996675, sequence=488, dist_traveled=16555.0),
#  Shape(id='151217', lat=-33.8698267, lon=150.8984799, sequence=489, dist_traveled=16829.0),
#  Shape(id='151217', lat=-33.8698612, lon=150.8983926, sequence=490, dist_traveled=16838.0),
#  Shape(id='151217', lat=-33.8699129, lon=150.8982508, sequence=491, dist_traveled=16852.0),
#  Shape(id='151217', lat=-33.8702226, lon=150.8973785, sequence=492, dist_traveled=16940.0),
#  Shape(id='151217', lat=-33.8703897, lon=150.8969182, sequence=493, dist_traveled=16986.0),
#  Shape(id='151217', lat=-33.8703897, lon=150.8969182, sequence=494, dist_traveled=17001.0),
#  Shape(id='151217', lat=-33.8705585, lon=150.8964514, sequence=495, dist_traveled=17048.0),
#  Shape(id='151217', lat=-33.8713007, lon=150.8943988, sequence=496, dist_traveled=17255.0),
#  Shape(id='151217', lat=-33.8713007, lon=150.8943988, sequence=497, dist_traveled=17268.0),
#  Shape(id='151217', lat=-33.8716347, lon=150.893474, sequence=498, dist_traveled=17361.0),
#  Shape(id='151217', lat=-33.8718153, lon=150.8929615, sequence=499, dist_traveled=17413.0),
#  Shape(id='151217', lat=-33.8719184, lon=150.8926671, sequence=500, dist_traveled=17442.0),
#  Shape(id='151217', lat=-33.8720415, lon=150.8923203, sequence=501, dist_traveled=17477.0),
#  Shape(id='151217', lat=-33.8720415, lon=150.8923203, sequence=502, dist_traveled=17491.0),
#  Shape(id='151217', lat=-33.8722195, lon=150.8918165, sequence=503, dist_traveled=17541.0),
#  Shape(id='151217', lat=-33.8722884, lon=150.8916311, sequence=504, dist_traveled=17560.0),
#  Shape(id='151217', lat=-33.8722319, lon=150.890385, sequence=505, dist_traveled=17676.0),
#  Shape(id='151217', lat=-33.8722319, lon=150.890385, sequence=506, dist_traveled=17689.0),
#  Shape(id='151217', lat=-33.8721874, lon=150.8894176, sequence=507, dist_traveled=17779.0),
#  Shape(id='151217', lat=-33.872759, lon=150.8896262, sequence=508, dist_traveled=17845.0),
#  Shape(id='151217', lat=-33.872759, lon=150.8896262, sequence=509, dist_traveled=17859.0),
#  Shape(id='151217', lat=-33.8740102, lon=150.8900807, sequence=510, dist_traveled=18004.0),
#  Shape(id='151217', lat=-33.8740102, lon=150.8900807, sequence=511, dist_traveled=18020.0),
#  Shape(id='151217', lat=-33.8742743, lon=150.8901769, sequence=512, dist_traveled=18050.0),
#  Shape(id='151217', lat=-33.8744294, lon=150.8902812, sequence=513, dist_traveled=18070.0),
#  Shape(id='151217', lat=-33.874368, lon=150.8893314, sequence=514, dist_traveled=18158.0),
#  Shape(id='151217', lat=-33.8743542, lon=150.8890507, sequence=515, dist_traveled=18184.0),
#  Shape(id='151217', lat=-33.8742551, lon=150.886956, sequence=516, dist_traveled=18378.0),
#  Shape(id='151217', lat=-33.8742286, lon=150.8864594, sequence=517, dist_traveled=18424.0),
#  Shape(id='151217', lat=-33.8741563, lon=150.8848722, sequence=518, dist_traveled=18572.0),
#  Shape(id='151217', lat=-33.8734255, lon=150.884847, sequence=519, dist_traveled=18653.0),
#  Shape(id='151217', lat=-33.8730186, lon=150.8848332, sequence=520, dist_traveled=18698.0),
#  Shape(id='151217', lat=-33.8730186, lon=150.8848332, sequence=521, dist_traveled=18713.0),
#  Shape(id='151217', lat=-33.8710527, lon=150.884765, sequence=522, dist_traveled=18931.0),
#  Shape(id='151217', lat=-33.871085, lon=150.8834995, sequence=523, dist_traveled=19048.0),
#  Shape(id='151217', lat=-33.8711039, lon=150.8830234, sequence=524, dist_traveled=19092.0),
#  Shape(id='151217', lat=-33.8711203, lon=150.8824069, sequence=525, dist_traveled=19149.0),
#  Shape(id='151217', lat=-33.8711268, lon=150.8822554, sequence=526, dist_traveled=19163.0),
#  Shape(id='151217', lat=-33.8711429, lon=150.8821469, sequence=527, dist_traveled=19173.0),
# ...
#  Shape(id='151217', lat=-33.8563008, lon=150.8952708, sequence=659, dist_traveled=23299.0),
#  Shape(id='151217', lat=-33.8564062, lon=150.8961609, sequence=660, dist_traveled=23382.0),
#  Shape(id='151217', lat=-33.8563973, lon=150.896172, sequence=661, dist_traveled=23384.0),
#  Shape(id='151217', lat=-33.8563795, lon=150.8961832, sequence=662, dist_traveled=23386.0),
#  Shape(id='151217', lat=-33.8563708, lon=150.896205, sequence=663, dist_traveled=23388.0),
#  Shape(id='151217', lat=-33.856371, lon=150.8962158, sequence=664, dist_traveled=23389.0),
#  Shape(id='151217', lat=-33.8563714, lon=150.8962374, sequence=665, dist_traveled=23391.0),
#  Shape(id='151217', lat=-33.8563808, lon=150.8962588, sequence=666, dist_traveled=23393.0),
#  Shape(id='151217', lat=-33.856399, lon=150.8962692, sequence=667, dist_traveled=23396.0),
#  Shape(id='151217', lat=-33.856417, lon=150.8962687, sequence=668, dist_traveled=23398.0),
#  Shape(id='151217', lat=-33.8565046, lon=150.8971744, sequence=669, dist_traveled=23482.0),
#  Shape(id='151217', lat=-33.8565109, lon=150.8980713, sequence=670, dist_traveled=23565.0),
#  Shape(id='151217', lat=-33.8556569, lon=150.898222, sequence=671, dist_traveled=23661.0),
#  Shape(id='151217', lat=-33.8543264, lon=150.8984599, sequence=672, dist_traveled=23810.0),
#  Shape(id='151217', lat=-33.8543014, lon=150.8985794, sequence=673, dist_traveled=23821.0),
#  Shape(id='151217', lat=-33.8542109, lon=150.8990896, sequence=674, dist_traveled=23870.0),
#  Shape(id='151217', lat=-33.8541534, lon=150.8994152, sequence=675, dist_traveled=23900.0),
#  Shape(id='151217', lat=-33.8541024, lon=150.8996002, sequence=676, dist_traveled=23918.0),
#  Shape(id='151217', lat=-33.8540241, lon=150.8997642, sequence=677, dist_traveled=23936.0),
#  Shape(id='151217', lat=-33.8538308, lon=150.9000607, sequence=678, dist_traveled=23971.0),
#  Shape(id='151217', lat=-33.8534358, lon=150.9006972, sequence=679, dist_traveled=24044.0),
#  Shape(id='151217', lat=-33.8532427, lon=150.9010045, sequence=680, dist_traveled=24080.0),
#  Shape(id='151217', lat=-33.8531991, lon=150.9010921, sequence=681, dist_traveled=24089.0),
#  Shape(id='151217', lat=-33.8531384, lon=150.9012341, sequence=682, dist_traveled=24104.0),
#  Shape(id='151217', lat=-33.8530777, lon=150.901376, sequence=683, dist_traveled=24119.0),
#  Shape(id='151217', lat=-33.8530352, lon=150.9015284, sequence=684, dist_traveled=24134.0),
#  Shape(id='151217', lat=-33.8530111, lon=150.9017019, sequence=685, dist_traveled=24150.0),
#  Shape(id='151217', lat=-33.853052, lon=150.9019819, sequence=686, dist_traveled=24176.0),
#  Shape(id='151217', lat=-33.8530722, lon=150.9021111, sequence=687, dist_traveled=24188.0),
#  Shape(id='151217', lat=-33.8531945, lon=150.9029402, sequence=688, dist_traveled=24266.0),
#  Shape(id='151217', lat=-33.8533768, lon=150.9041138, sequence=689, dist_traveled=24377.0),
#  Shape(id='151217', lat=-33.8535197, lon=150.9050938, sequence=690, dist_traveled=24469.0),
#  Shape(id='151217', lat=-33.8529896, lon=150.905204, sequence=691, dist_traveled=24528.0),
#  Shape(id='151217', lat=-33.8530243, lon=150.905442, sequence=692, dist_traveled=24551.0),
#  Shape(id='151217', lat=-33.8530243, lon=150.905442, sequence=693, dist_traveled=24568.0),
#  Shape(id='151217', lat=-33.8530609, lon=150.9056885, sequence=694, dist_traveled=24591.0),
#  Shape(id='151217', lat=-33.8531529, lon=150.9063239, sequence=695, dist_traveled=24651.0),
#  Shape(id='151217', lat=-33.8532126, lon=150.9066575, sequence=696, dist_traveled=24683.0),
#  Shape(id='151217', lat=-33.8532419, lon=150.9067865, sequence=697, dist_traveled=24695.0),
#  Shape(id='151217', lat=-33.8532612, lon=150.9068617, sequence=698, dist_traveled=24702.0),
#  Shape(id='151217', lat=-33.8533092, lon=150.9070334, sequence=699, dist_traveled=24719.0),
#  Shape(id='151217', lat=-33.8533749, lon=150.9071831, sequence=700, dist_traveled=24735.0),
#  Shape(id='151217', lat=-33.8538054, lon=150.9081128, sequence=701, dist_traveled=24833.0),
#  Shape(id='151217', lat=-33.8539737, lon=150.9084654, sequence=702, dist_traveled=24871.0),
#  Shape(id='151217', lat=-33.8540206, lon=150.9085723, sequence=703, dist_traveled=24882.0),
#  Shape(id='151217', lat=-33.8540351, lon=150.90868, sequence=704, dist_traveled=24892.0),
#  Shape(id='151217', lat=-33.8540351, lon=150.90868, sequence=705, dist_traveled=24909.0),
#  Shape(id='151217', lat=-33.8540412, lon=150.9087231, sequence=706, dist_traveled=24913.0),
#  Shape(id='151217', lat=-33.8542548, lon=150.9101553, sequence=707, dist_traveled=25047.0),
#  Shape(id='151217', lat=-33.8543675, lon=150.9109523, sequence=708, dist_traveled=25122.0),
#  Shape(id='151217', lat=-33.8543919, lon=150.9111149, sequence=709, dist_traveled=25138.0),
#  Shape(id='151217', lat=-33.8543919, lon=150.9111149, sequence=710, dist_traveled=25153.0),
#  Shape(id='151217', lat=-33.8544894, lon=150.9117599, sequence=711, dist_traveled=25214.0),
#  Shape(id='151217', lat=-33.8546633, lon=150.9129769, sequence=712, dist_traveled=25328.0),
#  Shape(id='151217', lat=-33.854745, lon=150.9135369, sequence=713, dist_traveled=25381.0),
#  Shape(id='151217', lat=-33.8547927, lon=150.9138546, sequence=714, dist_traveled=25411.0),
#  Shape(id='151217', lat=-33.8547927, lon=150.9138546, sequence=715, dist_traveled=25427.0),
#  Shape(id='151217', lat=-33.854806, lon=150.9139461, sequence=716, dist_traveled=25436.0),
#  Shape(id='151217', lat=-33.8550304, lon=150.9154861, sequence=717, dist_traveled=25580.0),
#  Shape(id='151217', lat=-33.8552149, lon=150.9167418, sequence=718, dist_traveled=25698.0),
#  Shape(id='151217', lat=-33.8552149, lon=150.9167418, sequence=719, dist_traveled=25719.0),
#  Shape(id='151217', lat=-33.8552852, lon=150.91722, sequence=720, dist_traveled=25764.0),
#  Shape(id='151217', lat=-33.8549347, lon=150.9172933, sequence=721, dist_traveled=25803.0),
#  Shape(id='151217', lat=-33.8541887, lon=150.9174303, sequence=722, dist_traveled=25887.0),
#  Shape(id='151217', lat=-33.8542621, lon=150.9179343, sequence=723, dist_traveled=25934.0),
#  Shape(id='151217', lat=-33.8542621, lon=150.9179343, sequence=724, dist_traveled=25953.0),
#  Shape(id='151217', lat=-33.8547179, lon=150.9210553, sequence=725, dist_traveled=26246.0),
#  Shape(id='151217', lat=-33.8547179, lon=150.9210553, sequence=726, dist_traveled=26261.0),
#  Shape(id='151217', lat=-33.8547596, lon=150.9213396, sequence=727, dist_traveled=26288.0),
#  Shape(id='151217', lat=-33.8547326, lon=150.9213402, sequence=728, dist_traveled=26291.0),
#  Shape(id='151217', lat=-33.8547147, lon=150.9213515, sequence=729, dist_traveled=26293.0),
#  Shape(id='151217', lat=-33.8547061, lon=150.9213733, sequence=730, dist_traveled=26295.0),
#  Shape(id='151217', lat=-33.8546973, lon=150.9213843, sequence=731, dist_traveled=26297.0),
#  Shape(id='151217', lat=-33.85468, lon=150.921428, sequence=732, dist_traveled=26301.0),
#  Shape(id='151217', lat=-33.8546805, lon=150.9214604, sequence=733, dist_traveled=26304.0),
#  Shape(id='151217', lat=-33.8546807, lon=150.9214712, sequence=734, dist_traveled=26305.0),
#  Shape(id='151217', lat=-33.8546901, lon=150.9214926, sequence=735, dist_traveled=26307.0),
#  Shape(id='151217', lat=-33.8547085, lon=150.9215138, sequence=736, dist_traveled=26310.0),
#  Shape(id='151217', lat=-33.8547178, lon=150.9215351, sequence=737, dist_traveled=26313.0),
#  Shape(id='151217', lat=-33.854736, lon=150.9215455, sequence=738, dist_traveled=26315.0),
#  Shape(id='151217', lat=-33.8547901, lon=150.9215442, sequence=739, dist_traveled=26321.0),
#  Shape(id='151217', lat=-33.8551248, lon=150.9238522, sequence=740, dist_traveled=26538.0),
#  Shape(id='151217', lat=-33.8551248, lon=150.9238522, sequence=741, dist_traveled=26552.0),
#  Shape(id='151217', lat=-33.8551677, lon=150.9241505, sequence=742, dist_traveled=26580.0),
#  Shape(id='151217', lat=-33.855239, lon=150.9246351, sequence=743, dist_traveled=26626.0),
#  Shape(id='151217', lat=-33.8556224, lon=150.9272737, sequence=744, dist_traveled=26874.0),
#  Shape(id='151217', lat=-33.8556224, lon=150.9272737, sequence=745, dist_traveled=26891.0),
#  Shape(id='151217', lat=-33.8557081, lon=150.9278661, sequence=746, dist_traveled=26947.0),
#  Shape(id='151217', lat=-33.8560339, lon=150.9300846, sequence=747, dist_traveled=27156.0),
#  Shape(id='151217', lat=-33.8560786, lon=150.9303839, sequence=748, dist_traveled=27184.0),
#  Shape(id='151217', lat=-33.8560786, lon=150.9303839, sequence=749, dist_traveled=27201.0),
#  Shape(id='151217', lat=-33.8561761, lon=150.9310322, sequence=750, dist_traveled=27262.0),
#  Shape(id='151217', lat=-33.8565657, lon=150.9336718, sequence=751, dist_traveled=27510.0),
#  Shape(id='151217', lat=-33.8565657, lon=150.9336718, sequence=752, dist_traveled=27528.0),
#  Shape(id='151217', lat=-33.8566543, lon=150.9342738, sequence=753, dist_traveled=27585.0),
#  Shape(id='151217', lat=-33.8568184, lon=150.9354587, sequence=754, dist_traveled=27696.0),
#  Shape(id='151217', lat=-33.8568399, lon=150.9356128, sequence=755, dist_traveled=27710.0),
#  Shape(id='151217', lat=-33.8568399, lon=150.9356128, sequence=756, dist_traveled=27724.0),
#  Shape(id='151217', lat=-33.8568902, lon=150.9359758, sequence=757, dist_traveled=27759.0),
#  Shape(id='151217', lat=-33.8569212, lon=150.9362128, sequence=758, dist_traveled=27781.0),
#  Shape(id='151217', lat=-33.8569908, lon=150.9366002, sequence=759, dist_traveled=27817.0),
#  Shape(id='151217', lat=-33.8570393, lon=150.9368044, sequence=760, dist_traveled=27837.0),
#  Shape(id='151217', lat=-33.8571135, lon=150.937089, sequence=761, dist_traveled=27865.0),
#  Shape(id='151217', lat=-33.8571135, lon=150.937089, sequence=762, dist_traveled=27883.0),
#  Shape(id='151217', lat=-33.8572706, lon=150.9376959, sequence=763, dist_traveled=27942.0),
#  Shape(id='151217', lat=-33.8572616, lon=150.9376961, sequence=764, dist_traveled=27943.0),
#  Shape(id='151217', lat=-33.857244, lon=150.9377182, sequence=765, dist_traveled=27946.0),
#  Shape(id='151217', lat=-33.8572353, lon=150.93774, sequence=766, dist_traveled=27948.0),
#  Shape(id='151217', lat=-33.8572268, lon=150.9377726, sequence=767, dist_traveled=27951.0),
#  Shape(id='151217', lat=-33.8572278, lon=150.9378266, sequence=768, dist_traveled=27956.0),
#  Shape(id='151217', lat=-33.8572369, lon=150.9378372, sequence=769, dist_traveled=27958.0),
#  Shape(id='151217', lat=-33.8572552, lon=150.9378476, sequence=770, dist_traveled=27960.0),
#  Shape(id='151217', lat=-33.8572643, lon=150.9378582, sequence=771, dist_traveled=27962.0),
#  Shape(id='151217', lat=-33.8572826, lon=150.9378685, sequence=772, dist_traveled=27964.0),
#  Shape(id='151217', lat=-33.8573096, lon=150.9378679, sequence=773, dist_traveled=27967.0),
#  Shape(id='151217', lat=-33.8573274, lon=150.9378567, sequence=774, dist_traveled=27969.0),
#  Shape(id='151217', lat=-33.8573651, lon=150.937953, sequence=775, dist_traveled=27979.0),
#  Shape(id='151217', lat=-33.8575863, lon=150.9387799, sequence=776, dist_traveled=28059.0),
#  Shape(id='151217', lat=-33.8577132, lon=150.9392492, sequence=777, dist_traveled=28105.0),
#  Shape(id='151217', lat=-33.8577132, lon=150.9392492, sequence=778, dist_traveled=28118.0),
#  Shape(id='151217', lat=-33.8578267, lon=150.9396712, sequence=779, dist_traveled=28159.0),
#  Shape(id='151217', lat=-33.8577998, lon=150.9396827, sequence=780, dist_traveled=28163.0),
#  Shape(id='151217', lat=-33.857791, lon=150.9396937, sequence=781, dist_traveled=28164.0),
#  Shape(id='151217', lat=-33.857765, lon=150.9397591, sequence=782, dist_traveled=28171.0),
#  Shape(id='151217', lat=-33.8577657, lon=150.9398024, sequence=783, dist_traveled=28175.0),
#  Shape(id='151217', lat=-33.8577749, lon=150.9398129, sequence=784, dist_traveled=28176.0),
#  Shape(id='151217', lat=-33.8577751, lon=150.9398237, sequence=785, dist_traveled=28177.0),
#  Shape(id='151217', lat=-33.8578027, lon=150.9398555, sequence=786, dist_traveled=28181.0),
#  Shape(id='151217', lat=-33.8578391, lon=150.9398762, sequence=787, dist_traveled=28186.0),
#  Shape(id='151217', lat=-33.8578842, lon=150.9398752, sequence=788, dist_traveled=28191.0),
#  Shape(id='151217', lat=-33.8581155, lon=150.9407667, sequence=789, dist_traveled=28277.0),
#  Shape(id='151217', lat=-33.8582656, lon=150.9413327, sequence=790, dist_traveled=28332.0),
#  Shape(id='151217', lat=-33.8582656, lon=150.9413327, sequence=791, dist_traveled=28348.0),
#  Shape(id='151217', lat=-33.8583753, lon=150.941744, sequence=792, dist_traveled=28388.0),
#  Shape(id='151217', lat=-33.8585882, lon=150.9425614, sequence=793, dist_traveled=28467.0),
#  Shape(id='151217', lat=-33.8585882, lon=150.9425614, sequence=794, dist_traveled=28483.0),
#  Shape(id='151217', lat=-33.8586354, lon=150.9427429, sequence=795, dist_traveled=28501.0),
#  Shape(id='151217', lat=-33.8587991, lon=150.9433658, sequence=796, dist_traveled=28561.0),
#  Shape(id='151217', lat=-33.8589446, lon=150.9439784, sequence=797, dist_traveled=28620.0),
#  Shape(id='151217', lat=-33.8593345, lon=150.9455168, sequence=798, dist_traveled=28769.0),
#  Shape(id='151217', lat=-33.8593345, lon=150.9455168, sequence=799, dist_traveled=28784.0),
#  Shape(id='151217', lat=-33.8593886, lon=150.9457295, sequence=800, dist_traveled=28805.0),
#  Shape(id='151217', lat=-33.8593796, lon=150.9457297, sequence=801, dist_traveled=28806.0),
#  Shape(id='151217', lat=-33.8593617, lon=150.9457409, sequence=802, dist_traveled=28808.0),
#  Shape(id='151217', lat=-33.8593352, lon=150.945774, sequence=803, dist_traveled=28812.0),
#  Shape(id='151217', lat=-33.8593266, lon=150.9457958, sequence=804, dist_traveled=28814.0),
#  Shape(id='151217', lat=-33.8593275, lon=150.9458498, sequence=805, dist_traveled=28819.0),
#  Shape(id='151217', lat=-33.8593278, lon=150.9458714, sequence=806, dist_traveled=28821.0),
#  Shape(id='151217', lat=-33.859337, lon=150.945882, sequence=807, dist_traveled=28823.0),
#  Shape(id='151217', lat=-33.8593464, lon=150.9459034, sequence=808, dist_traveled=28825.0),
#  Shape(id='151217', lat=-33.859374, lon=150.9459352, sequence=809, dist_traveled=28829.0),
#  Shape(id='151217', lat=-33.859392, lon=150.9459348, sequence=810, dist_traveled=28831.0),
#  Shape(id='151217', lat=-33.8594192, lon=150.9459449, sequence=811, dist_traveled=28834.0),
#  Shape(id='151217', lat=-33.8594371, lon=150.9459337, sequence=812, dist_traveled=28837.0),
#  Shape(id='151217', lat=-33.8594551, lon=150.9459332, sequence=813, dist_traveled=28839.0),
#  Shape(id='151217', lat=-33.8594639, lon=150.9459222, sequence=814, dist_traveled=28840.0),
#  Shape(id='151217', lat=-33.8594818, lon=150.945911, sequence=815, dist_traveled=28842.0),
#  Shape(id='151217', lat=-33.8595077, lon=150.9458455, sequence=816, dist_traveled=28849.0),
#  Shape(id='151217', lat=-33.8595072, lon=150.9458131, sequence=817, dist_traveled=28852.0),
#  Shape(id='151217', lat=-33.8599204, lon=150.9457167, sequence=818, dist_traveled=28899.0),
#  Shape(id='151217', lat=-33.8602169, lon=150.9456556, sequence=819, dist_traveled=28932.0),
#  Shape(id='151217', lat=-33.8604892, lon=150.9456004, sequence=820, dist_traveled=28963.0),
#  Shape(id='151217', lat=-33.8604892, lon=150.9456004, sequence=821, dist_traveled=28981.0),
#  Shape(id='151217', lat=-33.8607561, lon=150.9455454, sequence=822, dist_traveled=29011.0),
#  Shape(id='151217', lat=-33.8609717, lon=150.945497, sequence=823, dist_traveled=29036.0),
#  Shape(id='151217', lat=-33.8627329, lon=150.9451306, sequence=824, dist_traveled=29234.0),
#  Shape(id='151217', lat=-33.8627332, lon=150.9451522, sequence=825, dist_traveled=29236.0),
#  Shape(id='151217', lat=-33.8627426, lon=150.9451736, sequence=826, dist_traveled=29238.0),
#  Shape(id='151217', lat=-33.8627518, lon=150.9451841, sequence=827, dist_traveled=29240.0),
#  Shape(id='151217', lat=-33.8627612, lon=150.9452055, sequence=828, dist_traveled=29242.0),
#  Shape(id='151217', lat=-33.8627976, lon=150.9452263, sequence=829, dist_traveled=29246.0),
#  Shape(id='151217', lat=-33.8628336, lon=150.9452254, sequence=830, dist_traveled=29250.0),
#  Shape(id='151217', lat=-33.8629241, lon=150.9458901, sequence=831, dist_traveled=29313.0),
#  Shape(id='151217', lat=-33.8629235, lon=150.9458866, sequence=832, dist_traveled=29320.0)]

# %% [markdown]
# Because we have a primary key on trip, we can query even more simply
# using session.get

# %%
with Session() as session:
    shape = session.get(Trip, 1948209).shape

# %%
session = Session()

# %%
trip = session.get(Trip, 1948209)

# %%
trip.stop_times
# Out:
# [StopTime(trip_id='1948209', stop_id='2165100', arrival_time='15:10:00', departure_time='15:10:00', stop_sequence=1),
#  StopTime(trip_id='1948209', stop_id='2165101', arrival_time='15:11:00', departure_time='15:11:00', stop_sequence=2),
#  StopTime(trip_id='1948209', stop_id='2165138', arrival_time='15:15:00', departure_time='15:15:00', stop_sequence=3),
#  StopTime(trip_id='1948209', stop_id='2165139', arrival_time='15:17:00', departure_time='15:17:00', stop_sequence=4),
#  StopTime(trip_id='1948209', stop_id='2165140', arrival_time='15:18:00', departure_time='15:18:00', stop_sequence=5),
#  StopTime(trip_id='1948209', stop_id='2165207', arrival_time='15:18:00', departure_time='15:18:00', stop_sequence=6),
#  StopTime(trip_id='1948209', stop_id='2165140', arrival_time='15:18:00', departure_time='15:18:00', stop_sequence=7),
#  StopTime(trip_id='1948209', stop_id='2165141', arrival_time='15:19:00', departure_time='15:19:00', stop_sequence=8),
#  StopTime(trip_id='1948209', stop_id='2165142', arrival_time='15:19:00', departure_time='15:19:00', stop_sequence=9),
#  StopTime(trip_id='1948209', stop_id='216563', arrival_time='15:20:00', departure_time='15:20:00', stop_sequence=10),
#  StopTime(trip_id='1948209', stop_id='2176134', arrival_time='15:21:00', departure_time='15:21:00', stop_sequence=11),
#  StopTime(trip_id='1948209', stop_id='2176135', arrival_time='15:21:00', departure_time='15:21:00', stop_sequence=12),
#  StopTime(trip_id='1948209', stop_id='2176272', arrival_time='15:26:00', departure_time='15:26:00', stop_sequence=13),
#  StopTime(trip_id='1948209', stop_id='2176213', arrival_time='15:30:00', departure_time='15:30:00', stop_sequence=14),
#  StopTime(trip_id='1948209', stop_id='2176221', arrival_time='15:30:00', departure_time='15:30:00', stop_sequence=15),
#  StopTime(trip_id='1948209', stop_id='2176214', arrival_time='15:31:00', departure_time='15:31:00', stop_sequence=16),
#  StopTime(trip_id='1948209', stop_id='217648', arrival_time='15:32:00', departure_time='15:32:00', stop_sequence=17),
#  StopTime(trip_id='1948209', stop_id='2176288', arrival_time='15:34:00', departure_time='15:34:00', stop_sequence=18),
#  StopTime(trip_id='1948209', stop_id='217758', arrival_time='15:35:00', departure_time='15:35:00', stop_sequence=19),
#  StopTime(trip_id='1948209', stop_id='217774', arrival_time='15:36:00', departure_time='15:36:00', stop_sequence=20),
#  StopTime(trip_id='1948209', stop_id='217775', arrival_time='15:37:00', departure_time='15:37:00', stop_sequence=21),
#  StopTime(trip_id='1948209', stop_id='2177132', arrival_time='15:38:00', departure_time='15:38:00', stop_sequence=22),
#  StopTime(trip_id='1948209', stop_id='217765', arrival_time='15:39:00', departure_time='15:39:00', stop_sequence=23),
#  StopTime(trip_id='1948209', stop_id='217772', arrival_time='15:39:00', departure_time='15:39:00', stop_sequence=24),
#  StopTime(trip_id='1948209', stop_id='217757', arrival_time='15:40:00', departure_time='15:40:00', stop_sequence=25),
#  StopTime(trip_id='1948209', stop_id='2176118', arrival_time='15:40:00', departure_time='15:40:00', stop_sequence=26),
#  StopTime(trip_id='1948209', stop_id='2176119', arrival_time='15:41:00', departure_time='15:41:00', stop_sequence=27),
#  StopTime(trip_id='1948209', stop_id='2176120', arrival_time='15:41:00', departure_time='15:41:00', stop_sequence=28),
#  StopTime(trip_id='1948209', stop_id='2176121', arrival_time='15:42:00', departure_time='15:42:00', stop_sequence=29),
#  StopTime(trip_id='1948209', stop_id='2176122', arrival_time='15:42:00', departure_time='15:42:00', stop_sequence=30),
#  StopTime(trip_id='1948209', stop_id='216688', arrival_time='15:42:00', departure_time='15:42:00', stop_sequence=31),
#  StopTime(trip_id='1948209', stop_id='2176190', arrival_time='15:45:00', departure_time='15:45:00', stop_sequence=32),
#  StopTime(trip_id='1948209', stop_id='2176191', arrival_time='15:45:00', departure_time='15:45:00', stop_sequence=33),
#  StopTime(trip_id='1948209', stop_id='2176192', arrival_time='15:46:00', departure_time='15:46:00', stop_sequence=34),
#  StopTime(trip_id='1948209', stop_id='2176232', arrival_time='15:48:00', departure_time='15:48:00', stop_sequence=35),
#  StopTime(trip_id='1948209', stop_id='2176233', arrival_time='15:49:00', departure_time='15:49:00', stop_sequence=36),
#  StopTime(trip_id='1948209', stop_id='2176175', arrival_time='15:49:00', departure_time='15:49:00', stop_sequence=37),
#  StopTime(trip_id='1948209', stop_id='2176284', arrival_time='15:50:00', departure_time='15:50:00', stop_sequence=38),
#  StopTime(trip_id='1948209', stop_id='2176178', arrival_time='15:56:00', departure_time='15:56:00', stop_sequence=39),
#  StopTime(trip_id='1948209', stop_id='2176179', arrival_time='15:57:00', departure_time='15:57:00', stop_sequence=40),
#  StopTime(trip_id='1948209', stop_id='2176180', arrival_time='15:58:00', departure_time='15:58:00', stop_sequence=41),
#  StopTime(trip_id='1948209', stop_id='2176181', arrival_time='15:58:00', departure_time='15:58:00', stop_sequence=42),
#  StopTime(trip_id='1948209', stop_id='2176270', arrival_time='15:58:00', departure_time='15:58:00', stop_sequence=43),
#  StopTime(trip_id='1948209', stop_id='2176211', arrival_time='15:59:00', departure_time='15:59:00', stop_sequence=44),
#  StopTime(trip_id='1948209', stop_id='2176267', arrival_time='16:01:00', departure_time='16:01:00', stop_sequence=45),
#  StopTime(trip_id='1948209', stop_id='2176298', arrival_time='16:04:00', departure_time='16:04:00', stop_sequence=46),
#  StopTime(trip_id='1948209', stop_id='217678', arrival_time='16:04:00', departure_time='16:04:00', stop_sequence=47),
#  StopTime(trip_id='1948209', stop_id='217679', arrival_time='16:05:00', departure_time='16:05:00', stop_sequence=48),
#  StopTime(trip_id='1948209', stop_id='217680', arrival_time='16:06:00', departure_time='16:06:00', stop_sequence=49),
#  StopTime(trip_id='1948209', stop_id='217681', arrival_time='16:06:00', departure_time='16:06:00', stop_sequence=50),
#  StopTime(trip_id='1948209', stop_id='217682', arrival_time='16:07:00', departure_time='16:07:00', stop_sequence=51),
#  StopTime(trip_id='1948209', stop_id='217683', arrival_time='16:08:00', departure_time='16:08:00', stop_sequence=52),
#  StopTime(trip_id='1948209', stop_id='2176202', arrival_time='16:09:00', departure_time='16:09:00', stop_sequence=53),
#  StopTime(trip_id='1948209', stop_id='2176203', arrival_time='16:10:00', departure_time='16:10:00', stop_sequence=54),
#  StopTime(trip_id='1948209', stop_id='2176204', arrival_time='16:10:00', departure_time='16:10:00', stop_sequence=55),
#  StopTime(trip_id='1948209', stop_id='2176205', arrival_time='16:11:00', departure_time='16:11:00', stop_sequence=56),
#  StopTime(trip_id='1948209', stop_id='2176206', arrival_time='16:12:00', departure_time='16:12:00', stop_sequence=57),
#  StopTime(trip_id='1948209', stop_id='2176207', arrival_time='16:12:00', departure_time='16:12:00', stop_sequence=58),
#  StopTime(trip_id='1948209', stop_id='2164173', arrival_time='16:15:00', departure_time='16:15:00', stop_sequence=59),
#  StopTime(trip_id='1948209', stop_id='2164174', arrival_time='16:16:00', departure_time='16:16:00', stop_sequence=60),
#  StopTime(trip_id='1948209', stop_id='2164175', arrival_time='16:17:00', departure_time='16:17:00', stop_sequence=61),
#  StopTime(trip_id='1948209', stop_id='2164176', arrival_time='16:17:00', departure_time='16:17:00', stop_sequence=62),
#  StopTime(trip_id='1948209', stop_id='2164177', arrival_time='16:18:00', departure_time='16:18:00', stop_sequence=63),
#  StopTime(trip_id='1948209', stop_id='2164178', arrival_time='16:19:00', departure_time='16:19:00', stop_sequence=64),
#  StopTime(trip_id='1948209', stop_id='2164179', arrival_time='16:19:00', departure_time='16:19:00', stop_sequence=65),
#  StopTime(trip_id='1948209', stop_id='2164180', arrival_time='16:20:00', departure_time='16:20:00', stop_sequence=66),
#  StopTime(trip_id='1948209', stop_id='2164181', arrival_time='16:21:00', departure_time='16:21:00', stop_sequence=67),
#  StopTime(trip_id='1948209', stop_id='2164182', arrival_time='16:22:00', departure_time='16:22:00', stop_sequence=68),
#  StopTime(trip_id='1948209', stop_id='2164183', arrival_time='16:23:00', departure_time='16:23:00', stop_sequence=69),
#  StopTime(trip_id='1948209', stop_id='2164184', arrival_time='16:23:00', departure_time='16:23:00', stop_sequence=70),
#  StopTime(trip_id='1948209', stop_id='2164185', arrival_time='16:23:00', departure_time='16:23:00', stop_sequence=71),
#  StopTime(trip_id='1948209', stop_id='2164186', arrival_time='16:24:00', departure_time='16:24:00', stop_sequence=72),
#  StopTime(trip_id='1948209', stop_id='2164187', arrival_time='16:25:00', departure_time='16:25:00', stop_sequence=73),
#  StopTime(trip_id='1948209', stop_id='2164188', arrival_time='16:25:00', departure_time='16:25:00', stop_sequence=74),
#  StopTime(trip_id='1948209', stop_id='2164189', arrival_time='16:26:00', departure_time='16:26:00', stop_sequence=75),
#  StopTime(trip_id='1948209', stop_id='2164190', arrival_time='16:26:00', departure_time='16:26:00', stop_sequence=76),
#  StopTime(trip_id='1948209', stop_id='2164191', arrival_time='16:27:00', departure_time='16:27:00', stop_sequence=77)]

# %%
with Session() as session:
    stmt = select(Stop.lat, Stop.lon).join(StopTime).join(Trip).where(Trip.id == 1948209)
    df_stops = pd.DataFrame(session.execute(stmt).all())

pd.DataFrame(df_stops)
# Out:
#           lat         lon
# 0  -33.874556  150.928933
# 1  -33.874052  150.926752
# 2  -33.869601  150.924547
# 3  -33.868870  150.921433
# 4  -33.868485  150.919739
# ..        ...         ...
# 72 -33.858202  150.941371
# 73 -33.858521  150.942590
# 74 -33.859268  150.945538
# 75 -33.860533  150.945686
# 76 -33.862854  150.945900
#
# [77 rows x 2 columns]

# %%
df_route = pd.DataFrame.from_records(
    [(s.id, s.lat, s.lon) for s in shape], 
    columns=['shape_id', 'lat', 'lon']
)

# %%
fig = routemap(df_route)
add_positions(fig, df_stops)
