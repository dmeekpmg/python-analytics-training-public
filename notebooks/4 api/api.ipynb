# %% [markdown]
# # API connection
#
# https://medium.com/@bhaveshpatelaus/gtfs-realtime-vehicle-positions-using-python-and-databricks-tfnsw-a33b98f22e97

# %%
import os
from dotenv import load_dotenv
import requests
from pathlib import Path
import zipfile
import pandas as pd

from google.transit import gtfs_realtime_pb2
from google.transit import gtfs_realtime_pb2
from google.protobuf.json_format import MessageToDict
from google.protobuf.json_format import MessageToJson

from protobuf_to_dict import protobuf_to_dict

from data import data

load_dotenv()
# Out:
# True

# %%
FILENAME_SCHEDULE = 'gtfs.zip'

# %%
app_name = os.getenv("APP_NAME")
api_key = os.getenv("API_KEY")

# %%
BASE_URL = "https://api.transport.nsw.gov.au"
BUS_POSITION_URI = f"{BASE_URL}/v1/gtfs/vehiclepos/buses"
BUS_SCHEDULE_URI = f"{BASE_URL}/v1/gtfs/schedule/buses"
FERRY_POSITION = f"{BASE_URL}/v1/gtfs/historical"

# %%
headers = {
    "Authorization": f"apikey {api_key}"
}
request_details = dict(
    headers=headers,
    stream=True
)
# On our network, we need to add a certificate or the request will fail
# Look at the readme for instructions on how to set this up
if cert:=os.getenv("CERT", None):
    request_details['verify'] = cert

# %% [markdown]
# ## Extract schedules

# %%
response = requests.get(BUS_SCHEDULE_URI, **request_details)
response
# Out:
# <Response [200]>

# %%
zip_path = Path(data.path / FILENAME_SCHEDULE)

# %%
with open(zip_path, "wb") as f:
    f.write(response.content)

# %%
with zipfile.ZipFile(zip_path) as zip:
    print(zip.namelist())
# Out:
# ['agency.txt', 'calendar.txt', 'calendar_dates.txt', 'notes.txt', 'routes.txt', 'shapes.txt', 'stops.txt', 'stop_times.txt', 'trips.txt']

# %%
with zipfile.ZipFile(zip_path) as zip:
    for name in zip.namelist():
        with zip.open(name) as f:
            df = pd.read_csv(f)
            print(name)
            print(df.columns)
# Out:
# agency.txt
# Index(['agency_id', 'agency_name', 'agency_url', 'agency_timezone',
#        'agency_lang', 'agency_phone'],
#       dtype='object')
# calendar.txt
# Index(['service_id', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday',
#        'saturday', 'sunday', 'start_date', 'end_date'],
#       dtype='object')
# calendar_dates.txt
# Index(['service_id', 'date', 'exception_type'], dtype='object')
# notes.txt
# Index(['note_id', 'note_text'], dtype='object')
# routes.txt
# Index(['route_id', 'agency_id', 'route_short_name', 'route_long_name',
#        'route_desc', 'route_type', 'route_color', 'route_text_color'],
#       dtype='object')
# shapes.txt
# Index(['shape_id', 'shape_pt_lat', 'shape_pt_lon', 'shape_pt_sequence',
#        'shape_dist_traveled'],
#       dtype='object')
# stops.txt
# Index(['stop_id', 'stop_name', 'stop_lat', 'stop_lon', 'location_type',
#        'parent_station', 'wheelchair_boarding', 'platform_code'],
#       dtype='object')
# stop_times.txt
# Index(['trip_id', 'arrival_time', 'departure_time', 'stop_id', 'stop_sequence',
#        'stop_headsign', 'pickup_type', 'drop_off_type', 'shape_dist_traveled',
#        'timepoint', 'stop_note'],
#       dtype='object')
# trips.txt
# Index(['route_id', 'service_id', 'trip_id', 'shape_id', 'trip_headsign',
#        'direction_id', 'block_id', 'wheelchair_accessible', 'trip_note',
#        'route_direction'],
#       dtype='object')

# %%
with zipfile.ZipFile(zip_path) as z:
   with z.open("calendar.txt") as f:
      calendar = pd.read_csv(f)
      print(calendar.head())    # print the first 5 rows
# Out:
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0           1       0        0          0         0       0         1       0
# 1           2       1        1          1         1       1         0       1
# 2           3       0        1          0         0       0         0       0
# 3           4       0        0          0         0       1         0       0
# 4           5       1        1          1         1       1         0       0
#
#    start_date  end_date
# 0    20230909  20240727
# 1    20230910  20231231
# 2    20230912  20230919
# 3    20230908  20231229
# 4    20230911  20231229

# %%
with zipfile.ZipFile(zip_path) as z:
   with z.open("trips.txt") as f:
      trips = pd.read_csv(f)
      print(trips.head())    # print the first 5 rows
# Out:
#     route_id  service_id  trip_id  shape_id     trip_headsign  direction_id  \
# 0  2447_S886         294  1000095     79361     Mount View HS             1
# 1  2447_S871         294  1000097     79367     Mount View HS             1
# 2  2447_S879         294  1000103     79353       Cessnock PS             1
# 3  2454_8615         294  1000377     44723  Blaxland Station             0
# 4  2454_8311         294  1000381     44720  Warrimoo Primary             1
#
#    block_id  wheelchair_accessible  trip_note  \
# 0       NaN                      2        NaN
# 1       NaN                      2        NaN
# 2       NaN                      2        NaN
# 3       NaN                      2        NaN
# 4       NaN                      2        NaN
#
#                                      route_direction
# 0               Pelton to Mount View HS via Ellalong
# 1  Middle Rd after Dunlop Dr to Mount View HS via...
# 2  Millfield Rd opp Irwin Cr to Cessnock PS via A...
# 3                    Warrimoo PS to Blaxland Station
# 4  Wycliffe Christian School to Blaxland & Warrim...

# %%
# Check for uniqueness
trips[trips[['route_id', 'trip_id']].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [route_id, service_id, trip_id, shape_id, trip_headsign, direction_id, block_id, wheelchair_accessible, trip_note, route_direction]
# Index: []

# %%
# This trip hits the same stop twice within the same minute
# Would be an interesting case to map using the model
df[df.trip_id == 1948209].head(20)
# Out:
#          trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 2261020  1948209     15:10:00       15:10:00  2165100              1
# 2261021  1948209     15:11:00       15:11:00  2165101              2
# 2261022  1948209     15:15:00       15:15:00  2165138              3
# 2261023  1948209     15:17:00       15:17:00  2165139              4
# 2261024  1948209     15:18:00       15:18:00  2165140              5
# 2261025  1948209     15:18:00       15:18:00  2165207              6
# 2261026  1948209     15:18:00       15:18:00  2165140              7
# 2261027  1948209     15:19:00       15:19:00  2165141              8
# 2261028  1948209     15:19:00       15:19:00  2165142              9
# 2261029  1948209     15:20:00       15:20:00   216563             10
# 2261030  1948209     15:21:00       15:21:00  2176134             11
# 2261031  1948209     15:21:00       15:21:00  2176135             12
# 2261032  1948209     15:26:00       15:26:00  2176272             13
# 2261033  1948209     15:30:00       15:30:00  2176213             14
# 2261034  1948209     15:30:00       15:30:00  2176221             15
# 2261035  1948209     15:31:00       15:31:00  2176214             16
# 2261036  1948209     15:32:00       15:32:00   217648             17
# 2261037  1948209     15:34:00       15:34:00  2176288             18
# 2261038  1948209     15:35:00       15:35:00   217758             19
# 2261039  1948209     15:36:00       15:36:00   217774             20
#
#          stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# 2261020            NaN            0              0                    0
# 2261021            NaN            0              0                  219
# 2261022            NaN            0              0                  854
# 2261023            NaN            0              0                 1168
# 2261024            NaN            0              0                 1345
# 2261025            NaN            0              0                 1448
# 2261026            NaN            0              0                 1567
# 2261027            NaN            0              0                 1704
# 2261028            NaN            0              0                 1961
# 2261029            NaN            0              0                 2108
# 2261030            NaN            0              0                 2534
# 2261031            NaN            0              0                 2665
# 2261032            NaN            0              0                 4230
# 2261033            NaN            0              0                 5555
# 2261034            NaN            0              0                 5789
# 2261035            NaN            0              0                 6018
# 2261036            NaN            0              0                 6413
# 2261037            NaN            0              0                 6915
# 2261038            NaN            0              0                 7461
# 2261039            NaN            0              0                 7718
#
#          timepoint  stop_note
# 2261020          1        NaN
# 2261021          0        NaN
# 2261022          1        NaN
# 2261023          0        NaN
# 2261024          0        NaN
# 2261025          1        NaN
# 2261026          0        NaN
# 2261027          0        NaN
# 2261028          0        NaN
# 2261029          0        NaN
# 2261030          0        NaN
# 2261031          0        NaN
# 2261032          0        NaN
# 2261033          0        NaN
# 2261034          0        NaN
# 2261035          0        NaN
# 2261036          0        NaN
# 2261037          0        NaN
# 2261038          0        NaN
# 2261039          1        NaN

# %% [markdown]
# ## Realtime locations

# %%
from data import realtime

# %%
positions = realtime.get_latest_positions()

# %%
df = realtime.get_positions_dataframe(positions)
df.head()
# Out:
#                                id  trip_id   route_id  schedule_relationship  \
# 0      43280_230008897_2509_311_1  1915205   2509_311                      0
# 1     43280_230154508_2509_377X_1  1600121  2509_377X                      0
# 2  43333_229284125888_2510_S132_1  1911632  2510_S132                      0
# 3      43264_206648951_2508_178_1  1890986   2508_178                      0
# 4      43332_207637896_2503_818_1  1968171   2503_818                      0
#
#          lat         lon bearing speed   timestamp  congestion_level stop_id  \
# 0 -33.871632  151.230362   186.0   5.6  1694671843                 0
# 1 -33.911194  151.238815   190.0   0.0  1694671841                 1
# 2 -33.918648  151.074432   246.0   9.5  1694671845                 1
# 3 -33.753304  151.285568    50.0  12.0  1694671771                 4
# 4 -33.826248  150.981461   104.0   4.1  1694671849                 4
#
#                        vehicle_id label  request_timestamp
# 0      43280_230008897_2509_311_1               1694671852
# 1     43280_230154508_2509_377X_1               1694671852
# 2  43333_229284125888_2510_S132_1               1694671852
# 3      43264_206648951_2508_178_1               1694671852
# 4      43332_207637896_2503_818_1               1694671852

# %%
print(len(df))
# Out:
# 3654

# %%
from visualisations import maps
maps.position_map(df.rename(columns={'latitude': 'lat', 'longitude': 'lon'}))

# %%
realtime.upload_realtime(df)

# %% [markdown]
# ## Schedule times

# %%
from datetime import datetime, timedelta
import sched, time

# %%
def fetch_times(start_time=datetime.now(), wait_time=60, max_iters=60):
    """Generator function to calculate the next refresh time. We use
    this rather than just waiting 60 seconds so that we can get exactly 60 requests in
    one hour and not be affected by the time taken to extract and save results.

    Args:
        start_time (_type_, optional): _description_. Defaults to datetime.now().
        wait_time (int, optional): _description_. Defaults to 60. max_iters (int,
        optional): _description_. Defaults to 60.

    Yields:
        _type_: _description_
    """
    next_time = start_time
    max_time = start_time + timedelta(0, max_iters * wait_time)
    while next_time < max_time:
        # If the time is in the past (e.g. we started the process late),
        # then jump to the next minute
        while next_time < datetime.now():
            next_time += timedelta(0, wait_time)

        yield next_time
        next_time += timedelta(0, wait_time)

# %%
# Generate times for today
now = datetime.now()
today = (now.year, now.month, now.day)
fetch_times = fetch_times(datetime(*today, 17, 0), 60)

# %%
def schedule_fetch(scheduler:sched.scheduler): 
    # schedule the next call first
    scheduler.enterabs(next(fetch_times), 1, schedule_fetch, (scheduler,))
    realtime.fetch_and_upload_positions()
    # then do your stuff

scheduler = sched.scheduler(time.time, time.sleep)
scheduler.enterabs(next(fetch_times), 1, schedule_fetch, (scheduler,))
scheduler.run()
# Out:
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# Doing stuff...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\repos\advanced_python\notebooks\api\api.ipynb Cell 24 line 1
#       <a href='vscode-notebook-cell:/c%3A/repos/advanced_python/notebooks/api/api.ipynb#X31sZmlsZQ%3D%3D?line=8'>9</a> my_scheduler = sched.scheduler(time.time, time.sleep)
#      <a href='vscode-notebook-cell:/c%3A/repos/advanced_python/notebooks/api/api.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> my_scheduler.enter(60, 1, do_something, (my_scheduler,))
# ---> <a href='vscode-notebook-cell:/c%3A/repos/advanced_python/notebooks/api/api.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> my_scheduler.run()
#
# File c:\Users\dmee1\Anaconda3\envs\advanced_python\Lib\sched.py:149, in scheduler.run(self, blocking)
#     147     if not blocking:
#     148         return time - now
# --> 149     delayfunc(time - now)
#     150 else:
#     151     action(*argument, **kwargs)
#
# KeyboardInterrupt:
